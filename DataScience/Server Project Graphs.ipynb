# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install dash
# %pip install plotly
# %pip install flask
# %pip install wordcloud
# %pip install nltk
# %pip install openai
# %pip install transformers
# %pip install python-bidi

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import dash
import plotly
import flask
from datetime import datetime, timedelta
from dash import dcc, html, Input, Output
import plotly.express as px
from wordcloud import WordCloud
import base64
import io
import random
import re
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
# nltk.download('vader_lexicon')
# nltk.download('punkt')
# nltk.download('stopwords')
import plotly.graph_objs as go
import openai
# from openai import OpenAI
import json
import os
from io import BytesIO
# from transformers import pipeline
from itertools import chain
from bidi.algorithm import get_display
import shutil
import os

# %%
usa_path = r"C:\Users\user\Desktop\ca debates\debates"
all_files = [f for f in os.listdir(usa_path) if f.endswith('.csv')]

# Create an empty list to store DataFrames
dfs = []
# column_names = ['date', 'debate_title', 'country', 'file_path']
# Loop over all files and read them into a DataFrame
for file in all_files:
    file_path = os.path.join(usa_path, file)
    print(file_path)
    try:
        df = pd.read_csv(file_path)
        # print(df)
        # df['date'] = pd.to_datetime(df['date'])
        df['date'] = pd.to_datetime(df['date'])
        dfs.append(df)
    except:
        print(file)

# # # Concatenate all DataFrames
new_df = pd.concat(dfs, ignore_index=True)
new_df['date'] = pd.to_datetime(new_df['date'], format='%Y-%m-%d') #, errors='coerce'
new_df['date'] = new_df['date'].dt.date
# new_df.drop(columns=['Unnamed: 0'], inplace=True)
new_df = new_df.dropna(subset=['debate_title'])
new_df
# # Save the concatenated DataFrame to a new CSV file (optional)
# output_path = 'path/to/save/concatenated_file.csv'
# # new_df.to_csv(output_path, index=False)
# with_il = pd.concat([new_df,new_df202], ignore_index=True)
# wanted_categories = ['Economy', 'Education', 'Environment', 'Foreign Policy', 'Healthcare', 'Judicial System', 'Military', 'Social Issues', 'Other']
# Out:
# C:\Users\user\Desktop\ca debates\debates\2024-07-17 13-51-49.071867.csv
# C:\Users\user\Desktop\ca debates\debates\2024-07-17 14-18-07.638762.csv
# C:\Users\user\Desktop\ca debates\debates\2024-07-17 14-33-10.432374.csv
# C:\Users\user\Desktop\ca debates\debates\2024-07-17 14-55-17.100041.csv
# C:\Users\user\Desktop\ca debates\debates\2024-07-17 15-09-54.198766.csv
# C:\Users\user\Desktop\ca debates\debates\2024-07-17 15-26-21.978738.csv
# C:\Users\user\Desktop\ca debates\debates\2024-07-17 15-37-48.235619.csv
# C:\Users\user\Desktop\ca debates\debates\2024-07-17 16-08-19.205494.csv
# C:\Users\user\Desktop\ca debates\debates\2024-07-17 16-14-14.623257.csv
# C:\Users\user\Desktop\ca debates\debates\2024-07-17 16-14-17.052105.csv
# C:\Users\user\Desktop\ca debates\debates\2024-07-17 16-40-03.977119.csv
# C:\Users\user\Desktop\ca debates\debates\2024-07-17 16-45-56.556282.csv
# C:\Users\user\Desktop\ca debates\debates\2024-07-17 17-00-10.238160.csv
# ...

# %%
new_df = new_df.dropna(subset=['debate_title'])
new_df

# %%
test1 = test1.dropna(subset=['debate_title'])

# %%
def swap_columns(df, col1, col2):
    cols = df.columns.tolist()
    idx1, idx2 = cols.index(col1), cols.index(col2)
    cols[idx1], cols[idx2] = cols[idx2], cols[idx1]
    df.columns = cols

# Swap 'col1' and 'col2'
swap_columns(new_df, 'file_path', 'members')

# %%
US2010 = new_df.copy()

# %%
Cadebates = new_df.copy()

# %%
a7a = pd.concat([news_dataframe, df_news], ignore_index=True)
a7a
# Out:
#                                                     title       date  \
# 0            New Year’s Day’s best TV: Doctor Who; Luther 2019-01-01
# 1       Sprinting, fartlek and Romanian deadlifts – ho... 2019-01-01
# 2       Dunedin Consort/Butt review – bravura Bach to ... 2019-01-01
# 3       January transfer window 2019: club-by-club gui... 2019-01-01
# 4       Manchester police scour Victoria station after... 2019-01-01
# ...                                                   ...        ...
# 280540                      Over-by-over: evening session 2006-11-26
# 280541                      Carol Klein: Salad for winter 2006-11-25
# 280542  Rugby union: Profile of England hooker George ... 2006-11-01
# 280543                           Every moment is precious 2006-11-30
# 280544                         Craig Taylor: Jesus Christ 2006-11-04
#
#                                                   content  country  \
# 0       Doctor Who 7pm, BBC One An unfamiliar New Year...        2
# ...

# %%
a7a['Category'] = a7a['Category'].apply(json.dumps)
a7a.to_csv('news1.csv', index=False)

# %%
a7a.to_csv('news.csv', index =False)

# %%
news_dataframe = pd.read_csv(r"C:\Users\user\Desktop\news.csv")
news_dataframe['Category'] = news_dataframe['Category'].apply(json.loads)
news_dataframe['date'] = pd.to_datetime(news_dataframe['date'], format='%Y-%m-%d')
news_dataframe
# Out:
#                                                     title       date  \
# 0            New Year’s Day’s best TV: Doctor Who; Luther 2019-01-01
# 1       Sprinting, fartlek and Romanian deadlifts – ho... 2019-01-01
# 2       Dunedin Consort/Butt review – bravura Bach to ... 2019-01-01
# 3       January transfer window 2019: club-by-club gui... 2019-01-01
# 4       Manchester police scour Victoria station after... 2019-01-01
# ...                                                   ...        ...
# 280540                      Over-by-over: evening session 2006-11-26
# 280541                      Carol Klein: Salad for winter 2006-11-25
# 280542  Rugby union: Profile of England hooker George ... 2006-11-01
# 280543                           Every moment is precious 2006-11-30
# 280544                         Craig Taylor: Jesus Christ 2006-11-04
#
#                                                   content  country  \
# 0       Doctor Who 7pm, BBC One An unfamiliar New Year...        2
# ...

# %%
news_dataframe['Category'][127629]

# %%
news_dataframe['country'].unique()

# %%
tet = tet.drop(columns=['index'])
tet

# %%
v3 = pd.concat([test1, full_df], ignore_index=True)
v3
# Out:
#              date                                       debate_title  country  \
# 0      2000-02-15      Modernization Of Benefits And Obligations Act      4.0
# 1      2000-02-15                                     Ways And Means      4.0
# 2      2000-02-15                                   Division No. 684      4.0
# 3      2000-02-15                                   Division No. 685      4.0
# 4      2000-02-14                               Canada Elections Act      4.0
# ...           ...                                                ...      ...
# 230216 2021-12-14  Stablecoins: How Do They Work, How Are They Us...      1.0
# 230217 2021-12-09  Disrupting Dangerous Algorithms: Addressing th...      1.0
# 230218 2021-12-15             Oversight of the U.S. Airline Industry      1.0
# 230219 2021-12-08  Protecting Kids Online: Instagram and Reforms ...      1.0
# 230220 2021-12-17  To authorize elements of the Department of Tra...      1.0
#
# ...

# %%
v3['Category'] = v3['Category'].apply(json.dumps)
v3.to_csv('v21.csv', index=False)

# %%
full_df = pd.read_csv(r"C:\Users\user\Desktop\v21.csv")
full_df['Category'] = full_df['Category'].apply(json.loads)
# full_df['date'] = full_df['date'].apply(lambda x: str(x).split(' ')[0] if pd.notna(x) else x)

# # Convert 'date' to datetime format
full_df['date'] = pd.to_datetime(full_df['date'], format='%Y-%m-%d', errors='coerce')
full_df
# Out:
#              date                                       debate_title  country  \
# 0      2000-02-15      Modernization Of Benefits And Obligations Act      4.0
# 1      2000-02-15                                     Ways And Means      4.0
# 2      2000-02-15                                   Division No. 684      4.0
# 3      2000-02-15                                   Division No. 685      4.0
# 4      2000-02-14                               Canada Elections Act      4.0
# ...           ...                                                ...      ...
# 230216 2021-12-14  Stablecoins: How Do They Work, How Are They Us...      1.0
# 230217 2021-12-09  Disrupting Dangerous Algorithms: Addressing th...      1.0
# 230218 2021-12-15             Oversight of the U.S. Airline Industry      1.0
# 230219 2021-12-08  Protecting Kids Online: Instagram and Reforms ...      1.0
# 230220 2021-12-17  To authorize elements of the Department of Tra...      1.0
#
# ...

# %% [markdown]
# # GRAPH 1

# %%
real_data = full_df.copy()
news_df1 = news_dataframe.copy()
def generate_outlier_text(outlier_points):
    outlier_texts = []
    for point in outlier_points:
        point_str = point.strftime('%Y-%m-%d')
        dfpoints = real_data[real_data['date'] == point_str]
        # print(paths)
        explanation = f"Outlier value: {point}\nAdditional information: "
        outlier_texts.append(explanation)
    return outlier_texts

def count_discussions_per_day(df):
    discussions_per_day = df.groupby(df['date'].dt.date).size()
    return discussions_per_day

# Function to manually count the number of articles per day
def count_articles_per_day(df):
    articles_per_day = df.groupby(df['date'].dt.date).size()
    return articles_per_day

min_date = real_data['date'].min()
max_date = real_data['date'].max()

# Get unique months from the real data
unique_months = sorted(real_data['date'].dt.month.unique())

# Define the layout
app = dash.Dash(__name__)
country_names = {1: 'United States', 2: "United Kingdom", 3: "Israel", 4: "Canada", 5: 'Tunisia'}

# Modify the layout to use country names instead of numeric codes
app.layout = html.Div([
    html.H1('Parliamentary Trend Analysis', style={'textAlign': 'center'}),
    html.Div([
        html.Label("Select Country:"),
        dcc.Dropdown(
            id='country-dropdown',
            options=[{'label': country_names[country], 'value': country} for country in real_data['country'].unique()],
            value=real_data['country'].unique()[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
    ], style={'margin-bottom': '10px'}),
    

    html.Div([
        html.Label("Select Category:"),
        dcc.Dropdown(
            id='category-dropdown',
            options=[{'label': category, 'value': category} for category in wanted_categories],
            value=wanted_categories[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
    ], style={'margin-bottom': '10px'}),

    html.Div([
        html.Label("Select Time Period:"),
        dcc.DatePickerRange(
            id='date-range-picker',
            min_date_allowed=min(real_data['date']),
            max_date_allowed=max(real_data['date']),
            initial_visible_month=max(real_data['date']),
            start_date=min(real_data['date']),
            end_date=max(real_data['date']),
            display_format='DD/MM/YYYY',
            style={'width': '45%', 'display': 'inline-block'}
        ),
    ], style={'margin-bottom': '10px'}),

    dcc.Graph(id='line-plot')
])

@app.callback(
    Output('line-plot', 'figure'),
    [Input('country-dropdown', 'value'),
     Input('category-dropdown', 'value'),
     Input('date-range-picker', 'start_date'),
     Input('date-range-picker', 'end_date')]
)
def update_graph(selected_country, selected_category, start_date, end_date):
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date) + pd.offsets.MonthEnd(0)  # Last day of the month
    # print(selected_category)
    # Ensure correct filtering conditions   
    # testing_df['Category'].apply(lambda x: selected_categories in x)
    filtered_discussions_df = real_data[(real_data['country'] == selected_country) & 
                                    (real_data['Category'].apply(lambda x: selected_category in x)) &  
                                    (real_data['date'] >= start_date) & 
                                    (real_data['date'] <= end_date)]
    # print(filtered_discussions_df)
    
    # Debugging: Print the filtered DataFrame to verify the filtering
    # print(f"Filtered DataFrame for {selected_country} and {selected_category}:")
    # print(filtered_discussions_df)
    if filtered_discussions_df.empty:
        # Return an empty plot with a message
        layout = go.Layout(title='No discussions found for the selected criteria',
                           xaxis_title='Date', yaxis_title='Count')
        return {'data': [], 'layout': layout}
    discussions_per_week = filtered_discussions_df.resample('W-Mon', on='date').size()

    Q1 = discussions_per_week.quantile(0.25)
    Q3 = discussions_per_week.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers_mask = (discussions_per_week < lower_bound) | (discussions_per_week > upper_bound)

    outlier_x = discussions_per_week.index[outliers_mask]
    outlier_y = discussions_per_week[outliers_mask]
    outlier_text = generate_outlier_text(outlier_x)

    discussion_trace = go.Scatter(x=discussions_per_week.index, y=discussions_per_week.values,
                                  mode='lines+markers', name='Discussions', line=dict(color='blue'))

    outlier_trace = go.Scatter(
        x=outlier_x, 
        y=outlier_y,
        mode='markers',
        marker=dict(color='red', symbol='line-ns-open', size = 20), 
        name='Outliers',
        text=outlier_text,
        connectgaps=False 
    )

    # y_start = [0] * len(outlier_x)
    # outlier_trace['y'] = list(zip(y_start, outlier_y))

    filtered_news_df = news_df1[(news_df1['country'] == selected_country) & 
                                    (news_df1['Category'].apply(lambda x: selected_category in x)) &  
                                    (news_df1['date'] >= start_date) & 
                                    (news_df1['date'] <= end_date)]
    if not filtered_news_df.empty:
        articles_per_week = filtered_news_df.resample('W-Mon', on='date').size()
        # articles_per_week = count_articles_per_day(filtered_news_df)

        articles_trace = go.Scatter(x=articles_per_week.index, y=articles_per_week.values,
                                    mode='lines+markers', name='News Articles', line=dict(color='red'), yaxis='y2')
        # layout = go.Layout(title=f'Discussions from {start_date.strftime("%B %Y")} to {end_date.strftime("%B %Y")} ({country_names[selected_country]}, {selected_category})',
        #                xaxis_title='Date', yaxis_title='Count', legend=dict(x=0, y=1, traceorder="normal"))
        actual_start_date = discussions_per_week.index.min()
        actual_end_date = discussions_per_week.index.max()
        layout = go.Layout(title=f'Discussions from {actual_start_date.strftime("%B %Y")} to {actual_end_date.strftime("%B %Y")} ({country_names[selected_country]}, {selected_category})',
                        xaxis_title='Date', yaxis=dict(title='Discussions Count'),
                        yaxis2=dict(title='News Articles Count', overlaying='y', side='right'),
                        legend=dict(x=0, y=1, traceorder="normal"))

        fig = go.Figure(data=[discussion_trace, outlier_trace, articles_trace], layout=layout)
    else:
        actual_start_date = discussions_per_week.index.min()
        actual_end_date = discussions_per_week.index.max()
        layout = go.Layout(title=f'Discussions from {actual_start_date.strftime("%B %Y")} to {actual_end_date.strftime("%B %Y")} ({country_names[selected_country]}, {selected_category})',
                        xaxis_title='Date', yaxis=dict(title='Discussions Count'),
                        legend=dict(x=0, y=1, traceorder="normal"))

        fig = go.Figure(data=[discussion_trace, outlier_trace,], layout=layout)
    return fig


if __name__ == '__main__':
    app.run_server(debug=True)

# %% [markdown]
# # WORDCLOUD GRAPH

# %%
real_data = full_df.copy()

# %%
app = dash.Dash(__name__)
df = real_data
# df4['Category'].apply(lambda x: selected_categories in x)
# Define the layout of the dashboard
country_names = {1: 'United States', 2: "United Kingdom", 3: "Israel", 4: "Canada", 5: 'Tunisia'}
parliamentary_stop_words_eng = [
    "Mr", "Madam", "Speaker", "President", "Member", "Members", "Honourable", 
    "Minister", "Government", "Opposition", "House", "Parliament", "Chair", 
    "Committee", "Debate", "Motion", "Bill", "Clause", "Question", "Answer", 
    "Vote", "Session", "Meeting", "Point", "Order", "Chairperson", "Colleague", 
    "Colleagues", "Gentleman", "Gentlemen", "Lady", "Ladies", "Sir", "Ma'am", 
    "Secretary", "Cabinet", "Prime", "Deputy", "Leader", "Chief", "Office", 
    "Official", "Policy", "Agenda", "Vote", "Yes", "No", "Abstain",
    "Mr", "Madam", "Speaker", "President", "Member", "Members", "Honourable", 
    "Minister", "Government", "Opposition", "House", "Parliament", "Chair", 
    "Committee", "Debate", "Motion", "Bill", "Clause", "Question", "Answer", 
    "Vote", "Session", "Meeting", "Point", "Order", "Chairperson", "Colleague", 
    "Colleagues", "Gentleman", "Gentlemen", "Lady", "Ladies", "Sir", "Ma'am", 
    "Secretary", "Cabinet", "Prime", "Deputy", "Leader", "Chief", "Office", 
    "Official", "Policy", "Agenda", "Vote", "Yes", "No", "Abstain", "Rt", 
    "Hon", "Lord", "Baroness", "Duke", "Duchess", "Viscount", "Viscountess", 
    "Earl", "Countess", "Marquess", "Marquessate", "Dame", "Majesty", "Prince", 
    "Princess", "Duke", "Duchess", "Archbishop", "Bishop", "Canon", "Reverend", 
    "Chaplain", "Clerk", "Treasurer", "Comptroller", "Usher", "Beadle", "Serjeant", 
    "Clerk", "Principal", "Registrar", "Provost", "Dean", "Bailiff", "Master", 
    "Commissioner", "Councillor", "Alderman", "Sheriff", "Recorder", "Mayor", 
    "Governor", "Agent", "Solicitor", "Advocate", "Prosecutor", "Defendant", 
    "Plaintiff", "Magistrate", "Constable", "Coroner", "Officer", "Inspector", 
    "Detective", "Sergeant", "Corporal", "Lieutenant", "Captain", "Major", 
    "Colonel", "Brigadier", "General", "Admiral", "Marshal", "Warrant", 'lord'
    , 'minister', 'government', 'noble'
]

hebrew_stop_words = [
    "ה", "של", "על", "עם", "ש", "כ", "הם", "אני", "אנחנו", "אתה", "את", "אתם",
    "אתן", "הוא", "היא", "הם", "הן", "זה", "זאת", "אלה", "אלו", "מה", "מי", 
    "לא", "כן", "אם", "או", "כל", "כמו", "כי", "אשר", "אף", "אבל", "עוד", 
    "למה", "איך", "היכן", "כאן", "שם", "איפה", "מתי", "כמה", "איזה", "ליד", 
    "מול", "אחרי", "לפני", "בין", "תחת", "מאחורי", "האם", "כדי", "למרות", 
    "מאוד", "יותר", "פחות", "גם", "רק", "שוב", "כמעט", "בדרך כלל", "לעתים קרובות", 
    "לפעמים", "אף פעם", "תמיד", "פעמים רבות", "מעטים", "רבים", "במידה", "יכול", 
    "יוכל", "מוצע", "ממליץ", "מומלץ", "פרופ'", 'ח"כ', "חברי הכנסת", "מזכיר", 
    "מזכירה", "ממשלה", "אופוזיציה", "יושב ראש", "הצעה", "חוק", "סעיף", "שאלה", 
    "תשובה", "הצבעה", "ישיבה", "ישיבות", "נקודה", "סדר", "חבר", "חברים", "גברת", 
    "גבירותיי", "אדון", "אדונים", "שר", "שרים", "מזכירים", "הנשיא", "ראש הממשלה", 
    'מנכ"ל', "יועץ", "מדיניות", "תכנית", "סדר יום", "כן", "לא", "נמנע", 'הכנסת', 'בוועדה',
    'בוועדת', 'חברי הכנסת', 'הזה' ,'ואני', 'נוכח', 'נוכחת', 'חברת', 'שזה', 'שהוא', 'שלא', 'אינו', 'אינה',
    'הממשלה', 'שאנחנו', 'כבר', 'היום', 'הזאת', 'לך', 'חברי','ולא', 'הייתה', 'בממשלה', 'השר'
]

stop_words_english = set(nltk.corpus.stopwords.words('english')) | set(parliamentary_stop_words_eng)
stop_words_hebrew = set(nltk.corpus.stopwords.words('hebrew')) | set(hebrew_stop_words)
# Define the layout of the dashboard
app.layout = html.Div([
    html.H1('Wordcloud Graph', style={'textAlign': 'center'}),
    html.Div([
        html.Label('Country:'),
        dcc.Dropdown(
            id='country-dropdown',
            options=[{'label': country_names[country], 'value': country} for country in df['country'].unique()],
            value=df['country'].unique()[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
        html.Label('Category:'),
        dcc.Dropdown(
            id='category-dropdown',
            options=[{'label': category, 'value': category} for category in wanted_categories],
            value=wanted_categories[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
        html.Label('Discussion Title:'),
        dcc.Dropdown(
            id='debate-dropdown',
            style={'width': '45%', 'display': 'inline-block'}
        ),
    ]),
    html.Div(id='wordcloud-container')  # Container for displaying the word cloud
])

@app.callback(
    [Output('debate-dropdown', 'options'),
     Output('debate-dropdown', 'value')],
    [Input('country-dropdown', 'value'),
     Input('category-dropdown', 'value')]
)
def update_discussion_options(selected_country, selected_category):
    filtered_df = real_data[real_data['country'] == selected_country]
    # print(filtered_df)
    if selected_category:
        # Filter based on the selected category
        filtered_df = filtered_df[filtered_df['Category'].apply(lambda x: selected_category in x)]
    else:
        # If no category is selected, show all discussions
        filtered_df = real_data[real_data['country'] == selected_country]
    
    # Extract unique categories from the filtered DataFrame
    # all_categories = set(chain.from_iterable(filtered_df['Category']))
    # Create options for discussions, including both single category and multi-category items
    discussion_options = [{'label': discussion, 'value': discussion} for discussion in filtered_df['debate_title'].unique()]
    
    # Automatically select the first debate title if available
    if discussion_options:
        selected_discussion = discussion_options[0]['value']
        return discussion_options, selected_discussion
    else:
        return [], None

@app.callback(
    Output('wordcloud-container', 'children'),
    [Input('debate-dropdown', 'value'),
    Input('country-dropdown', 'value')]
)
def update_wordcloud(selected_debate,selected_country):
    if selected_debate is None:
        return html.Div()  # Return empty div if no debate is selected
    else:
        partial_path = df[df['debate_title'] == selected_debate]['file_path'].iloc[0]
        
        if selected_country == 4:
            initial_path = r"C:\Users\user\Desktop"
            ilflag = False
        elif selected_country == 2:
            initial_path = r'C:\Users\user\Desktop'
            ilflag = False
        elif selected_country == 1:
            initial_path = r'C:\Users\user\Desktop'
            ilflag = False
        elif selected_country == 3:
            initial_path = r"C:\Users\user\Desktop"
            ilflag = True
        
        path = os.path.join(initial_path, partial_path)
        with open(path, 'r', encoding='utf-8') as json_file:  # Ensure UTF-8 encoding
            alltext = json.load(json_file)
        
        full_text = ''
        for i in alltext:
            if selected_country == 4:
                for member, txt in i.items():
                    if member == '':
                        continue
                    full_text += txt
            else:
                if len(full_text + i['speech']) < 6000:
                    full_text += i['speech']
                else:
                    rem = 6000 - len(full_text)
                    full_text += i['speech'][:rem]      
        tokens = nltk.tokenize.word_tokenize(full_text)
        tokens_lower = [token.lower() for token in tokens]
        tokens_filtered = [re.sub(r'[^a-zA-Z0-9א-ת]', '', token) for token in tokens_lower]  # Include Hebrew characters in the regex
        tokens_filtered = [token for token in tokens_filtered if token]
        stop_words = stop_words_english if not ilflag else stop_words_hebrew
        tokens_filtered_stopwords = [token for token in tokens_filtered if token not in stop_words]
        preprocessed_text = ' '.join(tokens_filtered_stopwords)
        preprocessed_text = get_display(preprocessed_text)
        wordcloud = WordCloud(width=700, height=300, background_color='white', font_path=r"C:\Users\user\Desktop\OpenSans-Medium.ttf").generate(preprocessed_text)  # Specify your Hebrew font
        img_data = BytesIO()
        wordcloud.to_image().save(img_data, format='PNG')
        wordcloud_base64 = base64.b64encode(img_data.getvalue()).decode('utf-8')
        
        # Determine the directionality of text
        text_direction = 'rtl' if ilflag else 'ltr'
        
        # Return the wordcloud image as HTML
        return html.Img(src='data:image/png;base64,{}'.format(wordcloud_base64), style={'width': '90%', 'height': 'auto', 'direction': text_direction})

if __name__ == '__main__':
    app.run_server(debug=True)

# %% [markdown]
# # GRAPH 3

# %%
wanted_categories = ['Economy', 'Healthcare', 'Education', 'Military', 'Environment', 'Judicial System', 'Social Issues', 'Other','redo', 'Foreign Policy']

# %%
df3 = full_df.copy()

df3['date'] = pd.to_datetime(df3['date'], format='%Y-%m-%d', errors='coerce')
df3['Year'] = df3['date'].dt.year
df3['Year'] = df3['Year'].astype('Int64') 

country_names = {1: 'United States', 2: "United Kingdom", 3: "Israel", 4: "Canada", 5: 'Tunisia'} 
df3['Country'] = df3['country'].map(country_names)
df3['GlobalIssue'] = df3['Category'].apply(lambda x: [item for item in x])
# print(df3)
df3_exploded = df3.explode('GlobalIssue')

# Now, you can group by the exploded 'GlobalIssue' column
df_grouped = df3_exploded.groupby(['Year', 'Country', 'GlobalIssue']).size().reset_index(name='Discussions')
# df_grouped = df3.groupby(['Year', 'Country', 'GlobalIssue']).size().reset_index(name='Discussions')
# print(df_grouped)
df_grouped

# %%
app = dash.Dash(__name__)

# Extract unique values for dropdown options
unique_years = df_grouped['Year'].unique()
unique_countries = df_grouped['Country'].unique()
unique_global_issues = df_grouped['GlobalIssue'].unique()

country_colors = {
    'United States': '#EF553B',  # Default color for United States
    'United Kingdom': '#FFA15A',  # Default color for United Kingdom  US
    'Israel': '#636EFA',  # Default color for Israel
    'Canada': '#AB63FA',  # Default color for Canada
    'Tunisia': '#00CC96'  # Default color for Tunisia
}
# App layout
app.layout = html.Div([
    html.H1('Parliamentary Discussions Analysis', style={'textAlign': 'center'}),

    html.Div([
        # Time Filter Dropdown (Year)
        html.Div([
            html.Label('Select Time (Year):', style={'padding': '5px', 'fontSize': '20px'}),
            dcc.Dropdown(
                id='time-filter',
                options=[{'label': i, 'value': i} for i in unique_years],
                value=unique_years.tolist(),  # Default to all years
                multi=True,
                style={'width': '90%', 'margin': '5px'}
            )
        ], style={'width': '33%', 'display': 'inline-block'}),

        # Country Filter Dropdown
        html.Div([
            html.Label('Select Country:', style={'padding': '5px', 'fontSize': '20px'}),
            dcc.Dropdown(
                id='country-filter',
                options=[{'label': i, 'value': i} for i in unique_countries],
                value=unique_countries.tolist(),  # Default to all countries
                multi=True,
                style={'width': '90%', 'margin': '5px'}
            )
        ], style={'width': '33%', 'display': 'inline-block'}),

        # Global Issue Filter Dropdown
        html.Div([
            html.Label('Select Global Issue:', style={'padding': '5px', 'fontSize': '20px'}),
            dcc.Dropdown(
                id='global-issue-filter',
                options=[{'label': i, 'value': i} for i in wanted_categories],  # WANTED CATEGORIES AND NOT GLOBAL ISSUES
                value=[wanted_categories[0]],  # Default to first issue
                multi=True,
                style={'width': '90%', 'margin': '5px'}
            )
        ], style={'width': '33%', 'display': 'inline-block'})
    ], style={'display': 'flex', 'flexWrap': 'wrap'}),

    dcc.Graph(id='bar-chart')
])

# Callback to update the bar chart based on selected filters
@app.callback(
    Output('bar-chart', 'figure'),
    [Input('time-filter', 'value'),
     Input('country-filter', 'value'),
     Input('global-issue-filter', 'value')]
)
def update_chart(selected_years, selected_countries, selected_global_issues):
    # Filter the DataFrame to include only discussions about the selected years and countries
    filtered_df = df_grouped[
        (df_grouped['Year'].isin(selected_years)) &
        (df_grouped['Country'].isin(selected_countries))
    ].copy()  # Create a copy of the DataFrame
    # Calculate total discussions for each country in each year
    total_discussions_per_country = filtered_df.groupby(['Year', 'Country'])['Discussions'].transform('sum')

    # Filter the DataFrame to include only discussions about the selected global issues
    filtered_df_global = df_grouped[
        (df_grouped['GlobalIssue'].isin(selected_global_issues)) &
        (df_grouped['Year'].isin(selected_years)) &
        (df_grouped['Country'].isin(selected_countries))
    ].copy()

    # Calculate the total discussions for each country in each year about the selected global issues
    total_discussions_per_country_global = filtered_df_global.groupby(['Year', 'Country'])['Discussions'].transform('sum')

    # Calculate the percentage of discussions dedicated to the selected global issues for each country in each year
    filtered_df_global['Percentage'] = (filtered_df_global['Discussions'] / total_discussions_per_country) * 100
    fig = px.bar(
        filtered_df_global,
        x='Year',
        y='Percentage',
        color='Country',
        barmode='group',
        title='Global Issues Analysis',
        hover_data={'GlobalIssue': True},  # Include Discussions in hover data
        color_discrete_map=country_colors
    )
    
    # Customize hover text to include category information
    fig.update_traces(hovertemplate='<br>'.join([
        'Year: %{x}',
        'Category: %{customdata[0]}',
        'Percentage: %{y:.2f}%'  # Include percentage information
    ]))
    fig.update_yaxes(ticksuffix="%")


    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)

# %% [markdown]
# # Graph 4 works

# %%
import ast
full_df = pd.read_csv(r"C:\Users\user\Desktop\v14.csv")
full_df['Category'] = full_df['Category'].apply(json.loads)
full_df['date'] = pd.to_datetime(full_df['date'], format='%Y-%m-%d', errors='coerce')
# full_df['Category'] = full_df['Category'].apply(lambda x: [category.strip() for category in x[0].split(',')])

country_names = {1: 'United States', 2: "United Kingdom", 3: "Israel", 4: "Canada", 5: 'Tunisia'}
wanted_categories = ['Economy', 'Education', 'Environment', 'Foreign Policy', 'Healthcare', 'Judicial System', 'Military', 'Social Issues', 'Other']
df4 = full_df.copy()
sia = SentimentIntensityAnalyzer()


from translate import Translator
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import pandas as pd
import torch.nn.functional as F

# Load heBERT model and tokenizer

hebrew_tokenizer = AutoTokenizer.from_pretrained("avichr/heBERT_sentiment_analysis")
hebrew_model = AutoModelForSequenceClassification.from_pretrained("avichr/heBERT_sentiment_analysis")

def sentiment_score_he(texts):
    # Tokenize the input texts
    inputs = hebrew_tokenizer(texts, return_tensors="pt", padding=True, truncation=True, max_length=256)
    
    # Get the model output
    with torch.no_grad():
        outputs = hebrew_model(**inputs)
    logits = outputs.logits
    
    # Apply softmax to get probabilities
    probs = F.softmax(logits, dim=1)
    
    # Extract positive, neutral, and negative probabilities
    negative_probs = probs[:, 0].tolist()
    positive_probs = probs[:, 2].tolist()
    
    # Calculate the sentiment scores
    sentiments = [pos - neg for pos, neg in zip(positive_probs, negative_probs)]
    
    return sentiments

def sentiment_analysis_hebrew(partial_path):
    d = r'C:\Users\user\Desktop'
    path = os.path.join(d, partial_path)
    sent_dict = {}
    
    with open(path, 'r', encoding='utf-8') as json_file:
        alltext = json.load(json_file)

    # Preprocess texts and members
    texts, members = [], []
    for i in alltext:
        member = i['name'].lower()
        if len(member) > 70:
            continue
        text = i['speech']
        if len(text) > 500:
            text = text[:500]
        texts.append(text)
        members.append(member)

    # Batch processing
    batch_size = 16
    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        batch_members = members[i:i+batch_size]
        sentiment_scores = sentiment_score_he(batch_texts)
        
        for member, sentiment_score in zip(batch_members, sentiment_scores):
            if member not in sent_dict:
                sent_dict[member] = [sentiment_score, 1]
            else:
                sent_dict[member][0] += sentiment_score
                sent_dict[member][1] += 1

    for member, scores in sent_dict.items():
        sent_dict[member][0] /= scores[1]
        sent_dict[member] = round(sent_dict[member][0], 3)
    
    return sent_dict






# hebrew_tokenizer = AutoTokenizer.from_pretrained("avichr/heBERT_sentiment_analysis")
# hebrew_model = AutoModelForSequenceClassification.from_pretrained("avichr/heBERT_sentiment_analysis")

def translate_text(text, src_lang):
    translator = Translator(from_lang=src_lang, to_lang="en")
    try:
        # print(f"Original text: {text[:100]}...")  # Print only the first 100 characters to avoid huge output
        translated_text = translator.translate(text)
        # print(f"Translated text: {translated_text[:100]}...")  # Print only the first 100 characters to avoid huge output
        return translated_text
    except Exception as e:
        print(f"Error: {str(e)}")
        return f'Error: {str(e)}'

def sentiment_analysis(partial_path,country = 1):
    d = r'C:\Users\user\Desktop'
    path = os.path.join(d, partial_path)
    sent_dict = {}
    with open(path, 'r') as json_file:
        alltext = json.load(json_file)
    for i in alltext:
        member = i['name'].lower()  # Accessing the name directly
        if len(member) >70:
            continue
        text = i['speech']  # Accessing the speech text directly
        if len(text) > 2000:
            text = text[:2000]
        if country == 5:
            if len(text) > 250:
                text1 = text[:250]
            text = translate_text(text1,'ar')
        sentiment_scores = sia.polarity_scores(text)['compound']
        if member not in sent_dict.keys():
            sent_dict[member] = [float(sentiment_scores), 1]
        else:
            sent_dict[member][0] += float(sentiment_scores)
            sent_dict[member][1] += 1

    for i, j in sent_dict.items():
        sent_dict[i][0] /= sent_dict[i][1]
        sent_dict[i] = round(sent_dict[i][0], 3)
    return sent_dict


# def sentiment_score_he(text):
#     # Tokenize the input text
#     inputs = hebrew_tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    
#     # Get the model output
#     with torch.no_grad():
#         outputs = hebrew_model(**inputs)
#     logits = outputs.logits
    
#     # Apply softmax to get probabilities
#     probs = F.softmax(logits, dim=1)
    
#     # Extract positive, neutral, and negative probabilities
#     negative_prob = probs[0][0].item()
#     neutral_prob = probs[0][1].item()
#     positive_prob = probs[0][2].item()
    
#     # Calculate the sentiment score
#     sentiment = positive_prob - negative_prob
    
#     return sentiment

# def sentiment_analysis_hebrew(partial_path):
#     d = r'C:\Users\user\Desktop'
#     path = os.path.join(d, partial_path)
#     sent_dict = {}
#     with open(path, 'r', encoding='utf-8') as json_file:
#         alltext = json.load(json_file)
#     for i in alltext:
#         member = i['name'].lower()
#         if len(member) > 70:
#             continue
#         text = i['speech']
#         if len(text) > 2000:
#             text = text[:2000]
        
#         sentiment_score = sentiment_score_he(text)
#         if member not in sent_dict:
#             sent_dict[member] = [sentiment_score, 1]
#         else:
#             sent_dict[member][0] += sentiment_score
#             sent_dict[member][1] += 1

#     for member, scores in sent_dict.items():
#         sent_dict[member][0] /= scores[1]
#         sent_dict[member] = round(sent_dict[member][0], 3)
    
#     return sent_dict



def sentiment_color(sentiment):
    if sentiment < -0.25:
        return 'red'
    elif sentiment > 0.25:
        return 'green'
    else:
        return 'yellow'

def name_lower(name):
    return name.lower()


def clean_name(name):
    # Remove titles and other specific words
    name = re.sub(r'Mr\.|Ms\.|Mrs\.|Dr\.|Hon\.|Sir|Lord|Lady|Baron|mr\.|ms\.|mrs\.|dr\.|hon\.|sir|היו"ר|יו"ר|מזכירת|הכנסת|מזכיר', '', name)
    # Remove parentheses and their contents
    name = re.sub(r'\(.*?\)', '', name)
    # Remove trailing colons and any surrounding whitespace
    name = re.sub(r':\s*$', '', name).strip()
    return name

def match_name(name, names_list):
    cleaned_name = clean_name(name)
    pattern = re.compile(r'\b{}\b'.format(re.escape(cleaned_name.lower().strip())))
    # print(pattern)
    matches = [pattern.search(clean_name(n).lower().strip()) for n in names_list]
    matched_names = [names_list[i] for i in range(len(matches)) if matches[i] is not None]
    return matched_names if matched_names else None

def name_in_members(last_name, members_df):
    last_name_lower = last_name.lower()
    for member_name in members_df['name']:
        if last_name_lower in member_name.lower():
            return member_name
    return None

def truncate_title(title, max_length=90):
    try:
        if isinstance(title, str) and len(title) >= max_length:
            return title[:max_length].lower() + '...'
        return title.lower()
    except Exception as e:
        return title

df4['truncated_title'] = df4['debate_title'].apply(truncate_title)

CA_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\CA_members.csv')
IL_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\IL_members.csv')
TN_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\TN_members.csv')
UK_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\UK_members.csv')
US_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\US_members.csv')
app = dash.Dash(__name__)
app.layout = html.Div([
    html.H1("Parliamentarians' sentiment regarding the chosen discussion", style={'textAlign': 'center'}),
        html.Div([
            html.Label('Country:'),
            dcc.Dropdown(
                id='country-dropdown4',
                options=[{'label': country_names[country], 'value': country} for country in df4['country'].unique()],
                value=df4['country'].unique()[0],
                style={'width': '45%', 'display': 'inline-block'}
            ),
            html.Label('Category:'),
            dcc.Dropdown(
                id='category-dropdown4',
                options=[{'label': category, 'value': category} for category in wanted_categories],
                value=wanted_categories[0],
                style={'width': '45%', 'display': 'inline-block'}
            ),
            html.Label('Discussion Title:'),
            dcc.Dropdown(
                id='discussion-dropdown4',
                # options=[{'label': title, 'value': original_title} for title, original_title in zip(df4['truncated_title'], df4['debate_title'])],
                style={'width': '45%', 'display': 'inline-block'}
            ),
            
        ]),
        html.Div(id='discussion-info', style={'textAlign': 'center', 'margin': '20px 0', 'fontSize': '24px', 'fontWeight': 'bold'}),
        dcc.Graph(id='sentiment-graph')
])

@app.callback(
[Output('discussion-dropdown4', 'options'),
Output('discussion-dropdown4', 'value')],
[Input('country-dropdown4', 'value'),
Input('category-dropdown4', 'value')]
)
def update_discussion_options(selected_country, selected_category):
    filtered_df = df4[df4['country'] == selected_country]

    if selected_category:
        # Filter based on the selected category
        filtered_df = filtered_df[filtered_df['Category'].apply(lambda x: selected_category in x)]
    else:
        # If no category is selected, show all discussions
        filtered_df = df4[df4['country'] == selected_country]

    discussion_options = [{'label': truncate_title(discussion), 'value': discussion} 
                      for discussion in filtered_df['debate_title'].dropna().unique()
                      if discussion and truncate_title(discussion)]

    # Automatically select the first debate title if available
    if discussion_options:
        selected_discussion = discussion_options[0]['value']
        return discussion_options, selected_discussion
    else:
        return [], None
    
    
@app.callback(
    Output('sentiment-graph', 'figure'),
    Output('discussion-info', 'children'),
    [Input('country-dropdown4', 'value'),
    Input('category-dropdown4', 'value'),
    Input('discussion-dropdown4', 'value')]
)
def update_graph(selected_countries, selected_categories, selected_discussions):
    filtered_df = df4[
        (df4['country'] == selected_countries) &
        (df4['Category'].apply(lambda x: selected_categories in x)) &
        (df4['debate_title'].isin([selected_discussions]))
    ]
    
    discussion_date = filtered_df['date'].iloc[0].strftime('%d-%m-%Y')
    discussion_info = f"Country: {country_names[selected_countries]}, Category: {selected_categories}, Date: {discussion_date}"
    
    path = filtered_df['file_path'].tolist()
    sent_dict = {}
    US_flag = False
    if selected_countries == 4:
        sent_dict = sentiment_analysis(path[0])
        parties_df = CA_par
    elif selected_countries == 3:
        sent_dict = sentiment_analysis_hebrew(path[0])
        # print(sent_dict)
        parties_df = IL_par
        # print(parties_df)
    elif selected_countries == 2:
        sent_dict = sentiment_analysis(path[0])
        print(selected_discussions)
        print(discussion_date)
        print(f'UK SENT DICT: {sent_dict}')
        parties_df = UK_par
        parties_df['name'] = parties_df['name'].apply(clean_name)
    elif selected_countries == 1:
        sent_dict = sentiment_analysis(path[0])
        parties_df = US_par
        US_flag = True
    elif selected_countries == 5:
        sent_dict = sentiment_analysis(path[0], 5)
        parties_df = TN_par

    parties_df['startDate'] = pd.to_datetime(parties_df['startDate'])
    parties_df['endDate'] = pd.to_datetime(parties_df['endDate'])

    filtered_parties_df = parties_df[
        (parties_df['startDate'] <= discussion_date) &
        (parties_df['endDate'].isna() | (parties_df['endDate'] >= discussion_date))
    ]

    final_data = []
    reverse_lookup = {clean_name(key): key for key in sent_dict.keys()}
    for original_name, sentiment in sent_dict.items():
        cleaned_name = clean_name(original_name)
        # print(original_name)
        # print(cleaned_name)
        if cleaned_name in reverse_lookup:
            matched_names = match_name(cleaned_name, filtered_parties_df['name'].tolist())
            if matched_names:
                for matched_name in matched_names:
                    matched_row = filtered_parties_df[filtered_parties_df['name'] == matched_name]
                    original_matched_name = matched_row['name'].values[0]
                    party = matched_row['party'].values[0]
                    final_data.append((original_matched_name, sentiment, party))
                    break

    if final_data:
        merged_df = pd.DataFrame(final_data, columns=['matched_name', 'sentiment', 'party'])
    else:
        merged_df = pd.DataFrame([
        {'matched_name': name, 'sentiment': sent_dict.get(name, 0), 'party': 'No Party'} 
        for name in sent_dict.keys()
    ])
    
    if 'No Party' in merged_df['party'].unique() and not merged_df['party'].isnull().all():
        unique_parties = merged_df['party'].unique()
        party_to_y = {party: i for i, party in enumerate(unique_parties)}
        party_to_y['No Party'] = 0
    else:
        unique_parties = merged_df['party'].unique()
        party_to_y = {party: i for i, party in enumerate(unique_parties)}
    # print(selected_countries)
    # print(merged_df)
    merged_df['color'] = merged_df['sentiment'].apply(sentiment_color)
    merged_df['y_position'] = merged_df['party'].map(party_to_y)
    
    avg_sentiments = merged_df.groupby('party')['sentiment'].mean().reset_index()
    avg_sentiments['y_position'] = avg_sentiments['party'].map(party_to_y)
    avg_sentiments['color'] = avg_sentiments['sentiment'].apply(sentiment_color)
    
    fig = {
        'data': [
            go.Scatter(
                x=merged_df['sentiment'],
                y=merged_df['y_position'],
                text=[f'{row["matched_name"]} (Party: {row["party"]}, Sentiment: {row["sentiment"]})' for _, row in merged_df.iterrows()],
                mode='markers',
                marker={'size': 15, 'color': merged_df['color']}
            ),
            go.Scatter(
            x=avg_sentiments['sentiment'],
            y=avg_sentiments['y_position'],
            text=[f'Average Sentiment (Party: {row["party"]}, Sentiment: {row["sentiment"]})' for _, row in avg_sentiments.iterrows()],
            mode='markers',
            marker={'size': 20, 'color': avg_sentiments['color'], 'symbol': 'circle', 'opacity': 0.5},
            name='Average Sentiment'
        )
        ],
        'layout': go.Layout(
            title='MPs Sentiment by Party',
            xaxis={'title': 'Sentiment Score'},
            yaxis={'title': 'Party', 'tickvals': list(range(len(unique_parties))), 'ticktext': list(unique_parties)},
            hovermode='closest'
        )
    }
    return fig, discussion_info

if __name__ == '__main__':
    app.run_server(debug=True)

# %% [markdown]
# # EXPIRAMENTS

# %%
# from openai import OpenAI
# openai.my_api_key = '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'
client = openai.OpenAI(
    # This is the default and can be omitted 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
    api_key='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',
)

# %%
wanted_categories = ['Economy', 'Healthcare', 'Education', 'Military', 'Environment', 'Judicial System', 'Social Issues', 'Other', 'Foreign Policy']

# %%
dic = {1: "The United States", 2:"The United Kingdom", 3: "Israel", 4: "Canada", 5: "Tunisia"}
def categorizer(file,title,c):
    try:
        d = r'C:\Users\user\Desktop'
        file = os.path.join(d, file)
        with open(file, 'r') as json_file:
            alltext = json.load(json_file)
        
        partial_full_text = ''

        try:
            for speech_obj in alltext:
                speech = speech_obj.get('speech', '')  # Safely get the 'speech' value
                if len(partial_full_text + speech)  < 1500:
                    partial_full_text += speech
                else:
                    rem = 1500 - len(partial_full_text)
                    partial_full_text += speech[:rem]
                    break
        except Exception as e:
            print("Error: ", e)
        
        message = f"The following text is a transcription of a parliamentary debate in {dic[c]}, which of these following categories fit the text best? (Economy, Healthcare, Education, Military, Environment, Judicial System, Social Issues, Foreign Policy) (when none of the categories fit the text return the word 'Other').This is the debate title:{title}, and this is the text:{partial_full_text} /n answer with just the category. if more than one category is relevant return both as such (category1, category2,...)"
        # message = f"Out of the following categories (Economy, Healthcare, Education, Military, Natural Dissasters, Other), which fits this text the most? /n this is the text: {partial_full_text} /n answer with just the category"
        chat_completion = client.chat.completions.create(
                messages=[
                {
                    "role": "user",
                    "content": message,
                }
            ],
            model="gpt-3.5-turbo-1106", # gpt-3.5-turbo-1106 gpt-3.5-turbo-0125 gpt-4o
        )
        # print(partial_full_text)
        return chat_completion.choices[0].message.content
    except Exception as e:
        print(e)


def categorizer_IL(file,title):
    d = r'C:\Users\user\Desktop'
    file = os.path.join(d, file)
    with open(file, 'r') as json_file:
        alltext = json.load(json_file)
    
    partial_full_text = ''

    try:
        for speech_obj in alltext:
            speech = speech_obj.get('speech', '')  # Safely get the 'speech' value
            if len(partial_full_text + speech)  < 900:
                partial_full_text += speech
            else:
                rem = 900 - len(partial_full_text)
                partial_full_text += speech[:rem]
    except Exception as e:
        print("Error: ", e)
    
    message = f"The following text is a transcription of a parliamentary debate in israel, which of these following categories fit the text best? (Economy, Healthcare, Education, Military, Environment, Judicial System, Social Issues, Foreign Policy) (when none of the categories fit the text return the word 'Other').This is the debate title:{title}, and this is the text:{partial_full_text} /n answer with just the category. if more than one category is relevant return both as such (category1, category2,...)"
    # message = f"Out of the following categories (Economy, Healthcare, Education, Military, Natural Dissasters, Other), which fits this text the most? /n this is the text: {partial_full_text} /n answer with just the category"
    chat_completion = client.chat.completions.create(
            messages=[
            {
                "role": "user",
                "content": message,
            }
        ],
        model="gpt-3.5-turbo-1106",  # gpt-3.5-turbo-1106 gpt-3.5-turbo-0125 gpt-4o
    )
    # print(partial_full_text)
    return chat_completion.choices[0].message.content


def categorizer_TN(file,title):
    d = r'C:\Users\user\Desktop'
    file = os.path.join(d, file)
    with open(file, 'r') as json_file:
        alltext = json.load(json_file)

    partial_full_text = ''

    try:
        for speech_obj in alltext:
            speech = speech_obj.get('speech', '')  # Safely get the 'speech' value
            if len(partial_full_text) + len(speech)  < 700:
                partial_full_text += speech
            else:
                break
    except Exception as e:
        print("Error: ", e)
    
    message = f"The following text is a transcription of a parliamentary debate in arabic in tunisia, which of these following categories fit the text best? (Economy, Healthcare, Education, Military, Environment, Judicial System, Social Issues, Foreign Policy) (when none of the categories fit the text return the word 'Other').This is the debate title:{title}, and this is the text:{partial_full_text} /n answer with just the category. if more than one category is relevant return both as such (category1, category2,...)"
    # message = f"Out of the following categories (Economy, Healthcare, Education, Military, Natural Dissasters, Other), which fits this text the most? /n this is the text: {partial_full_text} /n answer with just the category"
    chat_completion = client.chat.completions.create(
            messages=[
            {
                "role": "user",
                "content": message,
            }
        ],
        model="gpt-3.5-turbo-0125", # gpt-3.5-turbo-1106 gpt-3.5-turbo-0125 gpt-4o
    )
    # print(partial_full_text)
    return chat_completion.choices[0].message.content


def news_categorizer(content,title, c):
    try:
        partial_full_text = ""
        if len(content) > 300:
            partial_full_text = content[:300]
        else:
            partial_full_text = content
        message = f"The following is the title and the content of a news article in {dic[c]}, I want you to categorize it as one of the following ['Economy', 'Healthcare', 'Education', 'Military', 'Environment', 'Judicial System', 'Social Issues', 'Foreign Policy'] (if none of the categories fit, return the word 'Other').This is the article's title:{title}, and this is the content:{partial_full_text} /n answer with just the category or 'Other'. if more than one category is relevant return both as such (category1, category2,...)"
        # message = f"Out of the following categories (Economy, Healthcare, Education, Military, Natural Dissasters, Other), which fits this text the most? /n this is the text: {partial_full_text} /n answer with just the category"
        chat_completion = client.chat.completions.create(
                messages=[
                {
                    "role": "user",
                    "content": message,
                }
            ],
            model="gpt-3.5-turbo-0125", # gpt-3.5-turbo-1106 gpt-3.5-turbo-0125 gpt-4o
        )
        # print(partial_full_text)
        return chat_completion.choices[0].message.content
    except Exception as e:
        print(e)
        return 'Other'

# %% [markdown]
# #### news

# %%
news_path = r"C:\Users\user\Desktop\USA news 2007"
all_files = [f for f in os.listdir(news_path) if f.endswith('.csv')]

dfs = []
for file in all_files:
    file_path = os.path.join(news_path, file)
    print(file_path)
    df = pd.read_csv(file_path)
    
    # Try parsing with different formats
    date_formats = ['%d/%m/%Y', '%Y-%m-%d']
    for fmt in date_formats:
        try:
            df['date'] = pd.to_datetime(df['date'], format=fmt)
            break  # Exit the loop if parsing is successful
        except ValueError:
            continue  # Try the next format if parsing fails

    dfs.append(df)

news_df = pd.concat(dfs, ignore_index=True)
news_df['date'] = pd.to_datetime(news_df['date'], format='%Y-%m-%d', errors='coerce')
news_df['date'] = news_df['date'].dt.date
# new_df.drop(columns=['id'], inplace=True)  # If you need to drop an extra index column
news_df
# Out:
# C:\Users\user\Desktop\USA news 2007\2024-07-08 23-23-14.740407.june.2007.csv
# C:\Users\user\Desktop\USA news 2007\2024-07-08 23-29-53.721312.january.2007.csv
# C:\Users\user\Desktop\USA news 2007\2024-07-09 00-46-56.597978.february.2007.csv
# C:\Users\user\Desktop\USA news 2007\2024-07-12 02-45-40.411995.march.2007.csv
# C:\Users\user\Desktop\USA news 2007\2024-07-12 03-50-16.363374.april.2007.csv
# C:\Users\user\Desktop\USA news 2007\2024-07-12 05-00-36.559736.may.2007.csv
# C:\Users\user\Desktop\USA news 2007\2024-07-12 06-06-53.112399.july.2007.csv
# C:\Users\user\Desktop\USA news 2007\2024-07-12 07-16-02.805633.august.2007.csv
# C:\Users\user\Desktop\USA news 2007\2024-07-12 08-17-11.144879.september.2007.csv
# C:\Users\user\Desktop\USA news 2007\2024-07-12 09-34-53.767520.october.2007.csv
# C:\Users\user\Desktop\USA news 2007\2024-07-12 10-43-04.567650.november.2007.csv
# C:\Users\user\Desktop\USA news 2007\2024-07-12 11-43-14.981117.december.2007.csv
# ...

# %%
n_test.drop(columns=['index'], inplace=True, errors='ignore')
n_test

# %%
len(UK1314)

# %%
news_df = news_df.dropna(subset=['content'])
news_df.reset_index(inplace=True, drop=True)
news_df
# max_date = test1['date'].max()
# min_date = test1['date'].min()

# print(f"Maximum date: {max_date}")
# print(f"Minimum date: {min_date}")

# %%
def sample_per_month_per_country(df, n=20):
    # Ensure the date column is in datetime format
    df['date'] = pd.to_datetime(df['date'])

    # Extract year and month for grouping
    df['year_month'] = df['date'].dt.to_period('M')

    sampled_list = []
    
    for country in df['country'].unique():
        # Filter the dataframe for the current country
        country_df = df[df['country'] == country]
        
        # Group by 'year_month' and 'country' and sample n rows per group
        grouped = country_df.groupby(['year_month', 'country'])
        sampled = grouped.apply(lambda x: x.sample(min(len(x), n), random_state=1))
        
        # Reset the index to avoid duplicate indices
        sampled = sampled.reset_index(drop=True)
        
        # Append the sampled dataframe to the list
        sampled_list.append(sampled)
    
    # Concatenate all the sampled dataframes
    final_sampled_df = pd.concat(sampled_list, ignore_index=True)
    
    return final_sampled_df

# Sample 10 rows per month per country in news_df
sampled_df = sample_per_month_per_country(news_df, n=450)

# Example of displaying the sampled DataFrame
print(sampled_df)
# Out:
#                                                  title       date  \
# 0              Pentagon stops F-14 parts sales to Iran 2007-01-31
# 1                  Scorpion delays Canada-bound flight 2007-01-10
# 2         Live Vote: More subsidies for nuclear power? 2007-01-22
# 3                   Barack Obama the FaceBook favorite 2007-01-31
# 4         La. serial slaying suspect pleads not guilty 2007-01-17
# ...                                                ...        ...
# 5395                   Yes, there's crying in politics 2007-12-19
# 5396     Russia emerges as powerhouse of foreign funds 2007-12-11
# 5397          Judges get OK to shorten crack sentences 2007-12-10
# 5398  Kenyan first lady’s slap later erased from video 2007-12-14
# 5399       10 gift ideas for the air travel enthusiast 2007-12-20
#
#                                                 content  country year_month
# 0     The Pentagon said Tuesday it had halted sales ...        1    2007-01
# ...

# %%
def split_dataframe(df, n):
    split_dfs = np.array_split(df, n)
    return split_dfs

# Split the DataFrame into 4 parts
split_dfs = split_dataframe(sampled_df, 4)

# Save each part as a separate CSV file
for i, split_df in enumerate(split_dfs):
    split_df.to_csv(f'sampled_part_UKNEWS{i+1}.csv', index=False)

# Example of displaying the first part of the split DataFrame
# print(split_dfs[0])

# %%
UKpart2 = pd.read_csv(r'C:\Users\user\Desktop\sampled_part_UKNEWS1.csv')
UKpart2['date'] = pd.to_datetime(UKpart2['date'], format='%Y-%m-%d', errors='coerce')
UKpart2
# Out:
#                                                    title       date  \
# 0      Formula one: Billionaire eyes major stake in J... 2005-01-17
# 1                     Parties clash on Labour's New Deal 2005-01-20
# 2                FA Cup: Sunderland 2 - 1 Crystal Palace 2005-01-09
# 3                    'Safe' bond leaves savers uncertain 2005-01-08
# 4                    Dove counters ad airbrushing claims 2005-01-04
# ...                                                  ...        ...
# 10282                      Over-by-over: evening session 2006-11-26
# 10283                      Carol Klein: Salad for winter 2006-11-25
# 10284  Rugby union: Profile of England hooker George ... 2006-11-01
# 10285                           Every moment is precious 2006-11-30
# 10286                         Craig Taylor: Jesus Christ 2006-11-04
#
#                                                  content  country year_month
# ...

# %%
CA0910 = news_df.copy()

# %%
us07 = sampled_df.copy()

# %%
UK0910

# %%
index

# %%
indices_to_remove = []

# Assuming UKnews is your DataFrame
for index, row in enumerate(UKpart2.iloc[0:].itertuples(), start=0):
    new_category = news_categorizer(row.content, row.title, row.country)
    UKpart2.at[index, 'Category'] = [new_category]
    print(new_category)
    if index % 1000 == 0:
        print("----------------------------------------------------------------")
        print(index)
        print("----------------------------------------------------------------")
    # time.sleep(3)
# Out:
# Foreign Policy
# ----------------------------------------------------------------
# 0
# ----------------------------------------------------------------
# Economy, Social Issues
# Other
# Economy
# Social Issues
# Sports
# Social Issues
# Social Issues
# Economy
# Other
# Other
# Social Issues
# Other
# Social Issues
# Social Issues
# Social Issues
# Social Issues
# Social Issues
# Other
# Other
# Foreign Policy
# Social Issues
# Economy
# Social Issues
# Sports
# Social Issues
# Education
# Education
# Social Issues
# Social Issues
# Economy
# Social Issues
# Military, Social Issues
# Other
# Social Issues
# Healthcare
# Other
# Other
# Social Issues
# Sports
# Other
# Other
# Foreign Policy
# Economy
# Economy, Technology
# Social Issues
# Social Issues
# Healthcare, Social Issues
# Other
# Social Issues
# Education
# Other
# Social Issues
# Healthcare, Social Issues
# Social Issues
# Social Issues
# Foreign Policy
# Education
# Other
# Foreign Policy
# Environment
# Economy
# ...

# %%
us07
# Out:
#                                                  title       date  \
# 0              Pentagon stops F-14 parts sales to Iran 2007-01-31
# 1                  Scorpion delays Canada-bound flight 2007-01-10
# 2         Live Vote: More subsidies for nuclear power? 2007-01-22
# 3                   Barack Obama the FaceBook favorite 2007-01-31
# 4         La. serial slaying suspect pleads not guilty 2007-01-17
# ...                                                ...        ...
# 5395                   Yes, there's crying in politics 2007-12-19
# 5396     Russia emerges as powerhouse of foreign funds 2007-12-11
# 5397          Judges get OK to shorten crack sentences 2007-12-10
# 5398  Kenyan first lady’s slap later erased from video 2007-12-14
# 5399       10 gift ideas for the air travel enthusiast 2007-12-20
#
#                                                 content  country year_month  \
# 0     The Pentagon said Tuesday it had halted sales ...        1    2007-01
# ...

# %%
CAnews1116

# %%
wanted_categories = ['Economy', 'Education', 'Environment', 'Foreign Policy', 'Healthcare', 'Judicial System', 'Military', 'Social Issues', 'Other']

# %%
indices_to_remove = []
for index, row in CAnews.iterrows():
    new_category = news_categorizer(row['content'],row['title'])
    CAnews.at[index, 'Category'] = [new_category]
    print(new_category)

# %%
n_test = UKpart2.copy()

# %%
# n_test = n_test.drop(['id'],axis = 1)
# n_test.reset_index(inplace=True)
n_test = n_test.dropna(subset=['content']).reset_index(drop=True)
n_test

# %%
def listfier(value):
    # Check if the value is a string
    if isinstance(value, str):
        return list(re.findall(r'\w+\s\w+|\w+', value))
    
    elif isinstance(value, list):
        return list(value)
    
    elif pd.isna(value):
        return ['redo']
    else:
        # If the value is already a list, return it as is (assuming this is possible)
        return list(value)
def filter_categories(categories):
    
    filtered_categories = [category for category in categories if category in wanted_categories]
    return filtered_categories if filtered_categories else ['Other']


def remove_other_if_needed(category_list):
    if len(category_list) >= 2 and 'Other' in category_list:
        category_list.remove('Other')
    return category_list

# Apply the function to the 'Category' column
n_test['Category'] = n_test['Category'].apply(str).apply(listfier)
n_test['Category'] = n_test['Category'].apply(filter_categories)
n_test['Category'] = n_test['Category'].apply(remove_other_if_needed)
# Apply the function to the 'Category' column
n_test
# Out:
#                                                    title       date  \
# 0      Formula one: Billionaire eyes major stake in J... 2005-01-17
# 1                     Parties clash on Labour's New Deal 2005-01-20
# 2                FA Cup: Sunderland 2 - 1 Crystal Palace 2005-01-09
# 3                    'Safe' bond leaves savers uncertain 2005-01-08
# 4                    Dove counters ad airbrushing claims 2005-01-04
# ...                                                  ...        ...
# 10282                      Over-by-over: evening session 2006-11-26
# 10283                      Carol Klein: Salad for winter 2006-11-25
# 10284  Rugby union: Profile of England hooker George ... 2006-11-01
# 10285                           Every moment is precious 2006-11-30
# 10286                         Craig Taylor: Jesus Christ 2006-11-04
#
#                                                  content  country year_month  \
# ...

# %%
n_test['Category'][1]
# Out:
# ['Economy', 'Social Issues']

# %%
# n_test['Category'] = n_test['Category'].apply(str).apply(listfier)
# n_test['Category'] = n_test['Category'].apply(filter_categories)
# def remove_other_if_needed(category_list):
#     if len(category_list) >= 2 and 'Other' in category_list:
#         category_list.remove('Other')
#     return category_list

# # Apply the function to the 'Category' column
# n_test['Category'] = n_test['Category'].apply(remove_other_if_needed)

# n_test
categories_flat = [category for sublist in n_test['Category'] for category in sublist]
unique_categories = set(categories_flat)
print(unique_categories)

# Get counts of each category
from collections import Counter
category_counts = Counter(categories_flat)
print(category_counts)
# Out:
# {'Healthcare', 'Social Issues', 'Judicial System', 'Foreign Policy', 'Environment', 'Other', 'Education', 'Economy', 'Military'}
# Counter({'Other': 3411, 'Social Issues': 3231, 'Economy': 1415, 'Foreign Policy': 1077, 'Healthcare': 537, 'Environment': 460, 'Education': 433, 'Judicial System': 430, 'Military': 229})

# %%
n_test['Category'][1]
# Out:
# ['Economy', 'Social Issues']

# %%
n_test['Category'] = n_test['Category'].apply(json.dumps)
n_test.to_csv('news_stam.csv',index=False)

# %%
df_news = pd.read_csv(r"C:\Users\user\Desktop\news_stam.csv")
df_news['Category'] = df_news['Category'].apply(json.loads)
df_news['date'] = pd.to_datetime(df_news['date'], format='%Y-%m-%d', errors='coerce')
# test1['Category'] = test1['Category'].apply(lambda x: [category.strip() for category in x[0].split(',')])
df_news['Category'][3]
# Out:
# ['Economy']

# %%
df_news['Category'][0]

# %%
wanted_categories = ['Economy', 'Healthcare', 'Education', 'Military', 'Environment', 'Judicial System', 'Social Issues', 'Other', 'Foreign Policy']

# %%
CA06 = new_df.copy()
CA06

# %% [markdown]
# #### discussions

# %%
wanted_categories = ['Economy', 'Education', 'Environment', 'Foreign Policy', 'Healthcare', 'Judicial System', 'Military', 'Social Issues', 'Other']

# %%
c = 0
indices_to_remove_CA = []
for idx in range(0, 46744):  # 5714 is exclusive in range, so it covers up to 5713
    if idx in full_df.index:
        row = full_df.loc[idx]
        if row['country'] == 2 and row['date'].year == 2023:  # Example condition
            try:
                new_category = categorizer(row['file_path'],row['debate_title'])
                full_df.at[idx, 'Category'] = [new_category]
                print(new_category)
            except Exception as e:
                indices_to_remove_CA.append(idx)
                print(row['file_path'])
                print(e)

# full_df.drop(indices_to_remove, inplace=True)

# # Reset index after dropping rows
# full_df.reset_index(drop=True, inplace=True)

# %%
error_rows = CA1315safer[CA1315safer['Category'].apply(lambda x: x == ['Error'])]

# Get the count of such rows
error_count = error_rows.shape[0]

# Get the indices of such rows
error_indices = error_rows.index.tolist()

print("Number of rows with category ['Error']:", error_count)
print("Indices of rows with category ['Error']:", error_indices)

# %%
# CA1315safer = CA1315safe.dropna(subset=['Category', 'debate_title'])
CA1315safer.reset_index(drop=True, inplace=True)
CA1315safer

# %%
USpart1 = pd.read_csv(r'C:\Users\user\Desktop\NOTerrorUSA06.csv')
USpart1['date'] = pd.to_datetime(USpart1['date'], format='%Y-%m-%d', errors='coerce')
USpart1

# %%
Cadebates
# Out:
#             date                                   debate_title country  \
# 0     2000-02-15  Modernization Of Benefits And Obligations Act       4
# 1     2000-02-15                                 Ways And Means       4
# 2     2000-02-15                               Division No. 684       4
# 3     2000-02-15                               Division No. 685       4
# 4     2000-02-14                           Canada Elections Act       4
# ...          ...                                            ...     ...
# 1701  2002-12-04                          Business of the House       4
# 1702  2002-12-03                                 Kyoto Protocol       4
# 1703  2002-12-03                       Auditor General's Report       4
# 1704  2002-12-03                 Nuclear Safety and Control Act       4
# 1705  2002-12-02                                 Kyoto Protocol       4
#
#                                              file_path
# ...

# %%
index

# %%
indices_to_remove = []

# Assuming UKnews is your DataFrame 
for index, row in enumerate(Cadebates.iloc[0:].itertuples(), start=0):
    if row.Category == ['Other']:
        # print(row)
        try:
            new_category = categorizer(row.file_path, row.debate_title, row.country)
        except Exception as e:
            new_category = 'Error'
            indices_to_remove.append(index)
            print(row.file_path)
            print(e)
        if index % 1000 == 0:
            print("------------------------------------------------------------------------")
            print(index)
            print("------------------------------------------------------------------------")
        # print(new_category)
        Cadebates.at[index, 'Category'] = [new_category]
        print(new_category)
# Out:
# Other
# Social Issues
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Healthcare
# Other
# Other
# Other
# Other
# Other
# Healthcare
# Other
# Other
# Economy, Social Issues
# Other
# Judicial System, Social Issues
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Judicial System, Economy
# Other
# Other
# Other
# Other
# Judicial System
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# Other
# ...

# %%
te1test = tet.copy()

# %%
te1test

# %%
# UK15181a
indices_to_remove

# %%
CA1315safe.drop(indices_to_remove, inplace=True)

# Reset index after dropping rows
CA1315safe.reset_index(drop=True, inplace=True)

# %%
# CA1315safe = CA1315.copy()
CA1315safe[100:150]

# %%
UK1518c = UK1518b.copy()
UK1518c

# %%
indices_to_remove = []
for index, row in UK1518.iterrows():
    try:
        new_category = categorizer(row['file_path'],row['debate_title'])
    except Exception as e:
        new_category = 'Error'
        indices_to_remove.append(index)
        print(row['file_path'])
        print(e)
    # print(new_category)
    UK1518.at[index, 'Category'] = [new_category]
    print(new_category)
# US2023.drop(indices_to_remove, inplace=True)

# # Reset index after dropping rows
# US2023.reset_index(drop=True, inplace=True)

# %%
te1 = Cadebates.copy()

# %%
te1
# Out:
#             date                                   debate_title country  \
# 0     2000-02-15  Modernization Of Benefits And Obligations Act       4
# 1     2000-02-15                                 Ways And Means       4
# 2     2000-02-15                               Division No. 684       4
# 3     2000-02-15                               Division No. 685       4
# 4     2000-02-14                           Canada Elections Act       4
# ...          ...                                            ...     ...
# 1701  2002-12-04                          Business of the House       4
# 1702  2002-12-03                                 Kyoto Protocol       4
# 1703  2002-12-03                       Auditor General's Report       4
# 1704  2002-12-03                 Nuclear Safety and Control Act       4
# 1705  2002-12-02                                 Kyoto Protocol       4
#
#                                              file_path  \
# ...

# %%
def remove_other_if_needed(category_list):
    if len(category_list) >= 2 and 'Other' in category_list:
        category_list.remove('Other')
    return category_list

# Apply the function to the 'Category' column
te1['Category'] = te1['Category'].apply(remove_other_if_needed)

te1
# Out:
#             date                                   debate_title country  \
# 0     2000-02-15  Modernization Of Benefits And Obligations Act       4
# 1     2000-02-15                                 Ways And Means       4
# 2     2000-02-15                               Division No. 684       4
# 3     2000-02-15                               Division No. 685       4
# 4     2000-02-14                           Canada Elections Act       4
# ...          ...                                            ...     ...
# 1701  2002-12-04                          Business of the House       4
# 1702  2002-12-03                                 Kyoto Protocol       4
# 1703  2002-12-03                       Auditor General's Report       4
# 1704  2002-12-03                 Nuclear Safety and Control Act       4
# 1705  2002-12-02                                 Kyoto Protocol       4
#
#                                              file_path  \
# ...

# %%
te1['Category'][1]

# %%
def listfier(value):
    # Check if the value is a string
    if isinstance(value, str):
        return list(re.findall(r'\w+\s\w+|\w+', value))
    
    elif isinstance(value, list):
        return list(value)
    
    elif pd.isna(value):
        return ['redo']
    else:
        # If the value is already a list, return it as is (assuming this is possible)
        return list(value)
    
te1['Category'] = te1['Category'].apply(str).apply(listfier)
te1
# Out:
#             date                                   debate_title country  \
# 0     2000-02-15  Modernization Of Benefits And Obligations Act       4
# 1     2000-02-15                                 Ways And Means       4
# 2     2000-02-15                               Division No. 684       4
# 3     2000-02-15                               Division No. 685       4
# 4     2000-02-14                           Canada Elections Act       4
# ...          ...                                            ...     ...
# 1701  2002-12-04                          Business of the House       4
# 1702  2002-12-03                                 Kyoto Protocol       4
# 1703  2002-12-03                       Auditor General's Report       4
# 1704  2002-12-03                 Nuclear Safety and Control Act       4
# 1705  2002-12-02                                 Kyoto Protocol       4
#
#                                              file_path  \
# ...

# %%
tet = te1[te1['Category'].apply(lambda x :x[0]) != 'Error']
errors = te1[te1['Category'].apply(lambda x :x[0]) == 'Error']

# %%
# errors.reset_index(inplace=True)
tet.reset_index(drop=True, inplace=True)
tet

# %%
err.date.unique()

# %% [markdown]
# Category fixing

# %%
wanted_categories = ['Economy', 'Education', 'Environment', 'Foreign Policy', 'Healthcare', 'Judicial System', 'Military', 'Social Issues', 'Other']
def filter_categories(categories):
    
    filtered_categories = [category for category in categories if category in wanted_categories]
    return filtered_categories if filtered_categories else ['Other']

# Apply the function to the 'Category' column
te1['Category'] = te1['Category'].apply(filter_categories)

# %%
categories_flat = [category for sublist in te1['Category'] for category in sublist]
# Get unique categories
unique_categories = set(categories_flat)
print(unique_categories)

# Get counts of each category
from collections import Counter
category_counts = Counter(categories_flat)
print(category_counts)
# Out:
# {'Healthcare', 'Social Issues', 'Judicial System', 'Foreign Policy', 'Environment', 'Other', 'Economy', 'Military'}
# Counter({'Other': 921, 'Economy': 313, 'Judicial System': 210, 'Environment': 132, 'Social Issues': 113, 'Foreign Policy': 100, 'Healthcare': 29, 'Military': 25})

# %%
len(te1)
# Out:
# 1706

# %%
te1['Category'] = te1['Category'].apply(json.dumps)
te1.to_csv('stam.csv',index=False)

# %%
test1 = pd.read_csv(r"C:\Users\user\Desktop\stam.csv")
test1['Category'] = test1['Category'].apply(json.loads)
test1['date'] = pd.to_datetime(test1['date'], format='%Y-%m-%d', errors='coerce')
# test1['Category'] = test1['Category'].apply(lambda x: [category.strip() for category in x[0].split(',')])
test1['Category'][0]
# Out:
# ['Social Issues']

# %% [markdown]
# 100 debates: 91 seconds, 0.04$

# %% [markdown]
# Party affiliation

# %% [markdown]
# Party Tester

# %%
is_word_present = parties_df['Name'].str.contains('shelly', case=False)

# Print the rows where the word is present
print(parties_df[is_word_present])

# %% [markdown]
# ### This graph is running on testing_df which is somewhat categorized, the categories are stored in a list and the list can contain multiple items

# %%
CA_members  =pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\CA_members.csv')
CA_members

# %%
TN_members = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\TN_members.csv')

# TN_members.drop(columns=['Unnamed: 0'], inplace=True)
# TN_members.to_csv(r'C:\Users\user\Desktop\Data\csv_files\members\TN_members.csv', index=False)
TN_members

# %%
IL_members = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\IL_members.csv')
# IL_members.drop(columns=['Unnamed: 0.1'], inplace=True)
IL_members

# %%
US_members = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\US_members.csv')
# IL_members.drop(columns=['Unnamed: 0.1'], inplace=True)
US_members

# %%
# UK_members = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\UK_members.csv')
# # UK_members.drop(columns=['Unnamed: 0'], inplace=True)
# # UK_members.to_csv(r'C:\Users\user\Desktop\Data\csv_files\members\UK_members.csv', index=False)
# UK_members
US_members
is_word_present = IL_members['name'].str.contains('אחמד טיבי', case=False)

# Print the rows where the word is present
print(IL_members[is_word_present])

# %%
full_df

# %%
import ast
full_df = pd.read_csv(r"C:\Users\user\Desktop\v13.csv")
full_df['Category'] = full_df['Category'].apply(json.loads)
full_df['date'] = pd.to_datetime(full_df['date'], format='%Y-%m-%d', errors='coerce')
# full_df['Category'] = full_df['Category'].apply(lambda x: [category.strip() for category in x[0].split(',')])

country_names = {1: 'United States', 2: "United Kingdom", 3: "Israel", 4: "Canada", 5: 'Tunisia'}
wanted_categories = ['Economy', 'Education', 'Environment', 'Foreign Policy', 'Healthcare', 'Judicial System', 'Military', 'Social Issues', 'Other']
df4 = full_df.copy()
sia = SentimentIntensityAnalyzer()


from translate import Translator
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import pandas as pd
import torch.nn.functional as F

# Load heBERT model and tokenizer
hebrew_tokenizer = AutoTokenizer.from_pretrained("avichr/heBERT_sentiment_analysis")
hebrew_model = AutoModelForSequenceClassification.from_pretrained("avichr/heBERT_sentiment_analysis")

def translate_text(text, src_lang):
    translator = Translator(from_lang=src_lang, to_lang="en")
    try:
        # print(f"Original text: {text[:100]}...")  # Print only the first 100 characters to avoid huge output
        translated_text = translator.translate(text)
        # print(f"Translated text: {translated_text[:100]}...")  # Print only the first 100 characters to avoid huge output
        return translated_text
    except Exception as e:
        print(f"Error: {str(e)}")
        return f'Error: {str(e)}'

def sentiment_analysis(partial_path,country = 1):
    d = r'C:\Users\user\Desktop'
    path = os.path.join(d, partial_path)
    sent_dict = {}
    with open(path, 'r') as json_file:
        alltext = json.load(json_file)
    for i in alltext:
        member = i['name'].lower()  # Accessing the name directly
        if len(member) >70:
            continue
        text = i['speech']  # Accessing the speech text directly
        if len(text) > 2000:
            text = text[:2000]
        if country == 5:
            if len(text) > 250:
                text1 = text[:250]
            text = translate_text(text1,'ar')
        sentiment_scores = sia.polarity_scores(text)['compound']
        if member not in sent_dict.keys():
            sent_dict[member] = [float(sentiment_scores), 1]
        else:
            sent_dict[member][0] += float(sentiment_scores)
            sent_dict[member][1] += 1

    for i, j in sent_dict.items():
        sent_dict[i][0] /= sent_dict[i][1]
        sent_dict[i] = round(sent_dict[i][0], 3)
    return sent_dict


def sentiment_score_he(text):
    # Tokenize the input text
    inputs = hebrew_tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
    
    # Get the model output
    with torch.no_grad():
        outputs = hebrew_model(**inputs)
    logits = outputs.logits
    
    # Apply softmax to get probabilities
    probs = F.softmax(logits, dim=1)
    
    # Extract positive, neutral, and negative probabilities
    negative_prob = probs[0][0].item()
    neutral_prob = probs[0][1].item()
    positive_prob = probs[0][2].item()
    
    # Calculate the sentiment score
    sentiment = positive_prob - negative_prob
    
    return sentiment

def sentiment_analysis_hebrew(partial_path):
    d = r'C:\Users\user\Desktop'
    path = os.path.join(d, partial_path)
    sent_dict = {}
    with open(path, 'r', encoding='utf-8') as json_file:
        alltext = json.load(json_file)
    for i in alltext:
        member = i['name'].lower()
        if len(member) > 70:
            continue
        text = i['speech']
        if len(text) > 2000:
            text = text[:2000]
        
        sentiment_score = sentiment_score_he(text)
        if member not in sent_dict:
            sent_dict[member] = [sentiment_score, 1]
        else:
            sent_dict[member][0] += sentiment_score
            sent_dict[member][1] += 1

    for member, scores in sent_dict.items():
        sent_dict[member][0] /= scores[1]
        sent_dict[member] = round(sent_dict[member][0], 3)
    
    return sent_dict



def sentiment_color(sentiment):
    if sentiment < -0.25:
        return 'red'
    elif sentiment > 0.25:
        return 'green'
    else:
        return 'yellow'

def name_lower(name):
    return name.lower()


def clean_name(name):
    # Remove titles and other specific words
    name = re.sub(r'Mr\.|Ms\.|Mrs\.|Dr\.|Hon\.|Sir|mr\.|ms\.|mrs\.|dr\.|hon\.|sir|היו"ר|יו"ר|מזכירת|הכנסת|מזכיר', '', name)
    # Remove parentheses and their contents
    name = re.sub(r'\(.*?\)', '', name)
    # Remove trailing colons and any surrounding whitespace
    name = re.sub(r':\s*$', '', name).strip()
    return name

def match_name(name, names_list):
    cleaned_name = clean_name(name)
    pattern = re.compile(r'\b{}\b'.format(re.escape(cleaned_name.lower().strip())))
    print(pattern)
    matches = [pattern.search(clean_name(n).lower().strip()) for n in names_list]
    matched_names = [names_list[i] for i in range(len(matches)) if matches[i] is not None]
    return matched_names if matched_names else None

def name_in_members(last_name, members_df):
    last_name_lower = last_name.lower()
    for member_name in members_df['name']:
        if last_name_lower in member_name.lower():
            return member_name
    return None

def truncate_title(title, max_length=90):
    try:
        if isinstance(title, str) and len(title) >= max_length:
            return title[:max_length].lower() + '...'
        return title.lower()
    except Exception as e:
        return title

df4['truncated_title'] = df4['debate_title'].apply(truncate_title)

CA_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\CA_members.csv')
IL_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\IL_members.csv')
TN_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\TN_members.csv')
UK_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\UK_members.csv')
US_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\US_members.csv')
app = dash.Dash(__name__)
app.layout = html.Div([
    html.H1("Parliamentarians' sentiment regarding the chosen discussion", style={'textAlign': 'center'}),
        html.Div([
            html.Label('Country:'),
            dcc.Dropdown(
                id='country-dropdown4',
                options=[{'label': country_names[country], 'value': country} for country in df4['country'].unique()],
                value=df4['country'].unique()[0],
                style={'width': '45%', 'display': 'inline-block'}
            ),
            html.Label('Category:'),
            dcc.Dropdown(
                id='category-dropdown4',
                options=[{'label': category, 'value': category} for category in wanted_categories],
                value=wanted_categories[0],
                style={'width': '45%', 'display': 'inline-block'}
            ),
            html.Label('Discussion Title:'),
            dcc.Dropdown(
                id='discussion-dropdown4',
                # options=[{'label': title, 'value': original_title} for title, original_title in zip(df4['truncated_title'], df4['debate_title'])],
                style={'width': '45%', 'display': 'inline-block'}
            ),
            
        ]),
        html.Div(id='discussion-info', style={'textAlign': 'center', 'margin': '20px 0', 'fontSize': '24px', 'fontWeight': 'bold'}),
        dcc.Graph(id='sentiment-graph')
])

@app.callback(
[Output('discussion-dropdown4', 'options'),
Output('discussion-dropdown4', 'value')],
[Input('country-dropdown4', 'value'),
Input('category-dropdown4', 'value')]
)
def update_discussion_options(selected_country, selected_category):
    filtered_df = df4[df4['country'] == selected_country]

    if selected_category:
        # Filter based on the selected category
        filtered_df = filtered_df[filtered_df['Category'].apply(lambda x: selected_category in x)]
    else:
        # If no category is selected, show all discussions
        filtered_df = df4[df4['country'] == selected_country]

    discussion_options = [{'label': truncate_title(discussion), 'value': discussion} 
                      for discussion in filtered_df['debate_title'].dropna().unique()
                      if discussion and truncate_title(discussion)]

    # Automatically select the first debate title if available
    if discussion_options:
        selected_discussion = discussion_options[0]['value']
        return discussion_options, selected_discussion
    else:
        return [], None
    
    
@app.callback(
    Output('sentiment-graph', 'figure'),
    Output('discussion-info', 'children'),
    [Input('country-dropdown4', 'value'),
    Input('category-dropdown4', 'value'),
    Input('discussion-dropdown4', 'value')]
)
def update_graph(selected_countries, selected_categories, selected_discussions):
    filtered_df = df4[
        (df4['country'] == selected_countries) &
        (df4['Category'].apply(lambda x: selected_categories in x)) &
        (df4['debate_title'].isin([selected_discussions]))
    ]
    
    discussion_date = filtered_df['date'].iloc[0].strftime('%d-%m-%Y')
    discussion_info = f"Country: {country_names[selected_countries]}, Category: {selected_categories}, Date: {discussion_date}"
    
    path = filtered_df['file_path'].tolist()
    sent_dict = {}
    US_flag = False
    if selected_countries == 4:
        sent_dict = sentiment_analysis(path[0])
        parties_df = CA_par
    elif selected_countries == 3:
        sent_dict = sentiment_analysis_hebrew(path[0])
        print(sent_dict)
        parties_df = IL_par
        print(parties_df)
    elif selected_countries == 2:
        sent_dict = sentiment_analysis(path[0])
        parties_df = UK_par
    elif selected_countries == 1:
        sent_dict = sentiment_analysis(path[0])
        parties_df = US_par
        US_flag = True
    elif selected_countries == 5:
        sent_dict = sentiment_analysis(path[0], 5)
        parties_df = TN_par

    parties_df['startDate'] = pd.to_datetime(parties_df['startDate'])
    parties_df['endDate'] = pd.to_datetime(parties_df['endDate'])

    filtered_parties_df = parties_df[
        (parties_df['startDate'] <= discussion_date) &
        (parties_df['endDate'].isna() | (parties_df['endDate'] >= discussion_date))
    ]

    final_data = []
    reverse_lookup = {clean_name(key): key for key in sent_dict.keys()}
    print('REVERSE LOOKUP: {reverse_lookup}')
    for original_name, sentiment in sent_dict.items():
        cleaned_name = clean_name(original_name)
        print(original_name)
        print(cleaned_name)
        if cleaned_name in reverse_lookup:
            matched_names = match_name(cleaned_name, filtered_parties_df['name'].tolist())
            if matched_names:
                for matched_name in matched_names:
                    matched_row = filtered_parties_df[filtered_parties_df['name'] == matched_name]
                    original_matched_name = matched_row['name'].values[0]
                    party = matched_row['party'].values[0]
                    final_data.append((original_matched_name, sentiment, party))
                    break

    if final_data:
        merged_df = pd.DataFrame(final_data, columns=['matched_name', 'sentiment', 'party'])
    else:
        merged_df = pd.DataFrame([
        {'matched_name': name, 'sentiment': sent_dict.get(name, 0), 'party': 'No Party'} 
        for name in sent_dict.keys()
    ])
    
    if 'No Party' in merged_df['party'].unique() and not merged_df['party'].isnull().all():
        unique_parties = merged_df['party'].unique()
        party_to_y = {party: i for i, party in enumerate(unique_parties)}
        party_to_y['No Party'] = 0
    else:
        unique_parties = merged_df['party'].unique()
        party_to_y = {party: i for i, party in enumerate(unique_parties)}

    merged_df['color'] = merged_df['sentiment'].apply(sentiment_color)
    merged_df['y_position'] = merged_df['party'].map(party_to_y)
    
    avg_sentiments = merged_df.groupby('party')['sentiment'].mean().reset_index()
    avg_sentiments['y_position'] = avg_sentiments['party'].map(party_to_y)
    avg_sentiments['color'] = avg_sentiments['sentiment'].apply(sentiment_color)
    
    fig = {
        'data': [
            go.Scatter(
                x=merged_df['sentiment'],
                y=merged_df['y_position'],
                text=[f'{row["matched_name"]} (Party: {row["party"]}, Sentiment: {row["sentiment"]})' for _, row in merged_df.iterrows()],
                mode='markers',
                marker={'size': 15, 'color': merged_df['color']}
            ),
            go.Scatter(
            x=avg_sentiments['sentiment'],
            y=avg_sentiments['y_position'],
            text=[f'Average Sentiment (Party: {row["party"]}, Sentiment: {row["sentiment"]})' for _, row in avg_sentiments.iterrows()],
            mode='markers',
            marker={'size': 20, 'color': avg_sentiments['color'], 'symbol': 'circle', 'opacity': 0.5},
            name='Average Sentiment'
        )
        ],
        'layout': go.Layout(
            title='MPs Sentiment by Party',
            xaxis={'title': 'Sentiment Score'},
            yaxis={'title': 'Party', 'tickvals': list(range(len(unique_parties))), 'ticktext': list(unique_parties)},
            hovermode='closest'
        )
    }
    return fig, discussion_info

if __name__ == '__main__':
    app.run_server(debug=True)

# %%
v2

# %%
import stanza

# Download Hebrew model
stanza.download('he')

# Download Arabic model
stanza.download('ar')

# %%
import stanza
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Initialize Stanza pipeline
def initialize_stanza_pipeline(lang):
    if lang == 'he':
        return stanza.Pipeline(lang='he', processors='tokenize,pos')
    elif lang == 'ar':
        return stanza.Pipeline(lang='ar', processors='tokenize,pos')
    else:
        raise ValueError("Unsupported language")

# Generate word cloud from text
def generate_wordcloud(text, lang='en'):
    # Initialize Stanza pipeline
    nlp = initialize_stanza_pipeline(lang)
    
    # Process the text with Stanza
    doc = nlp(text)

    # Extract meaningful tokens (nouns, adjectives, verbs)
    tokens = [word.text for sent in doc.sentences for word in sent.words if word.upos in ["NOUN", "ADJ", "VERB"]]

    # Join tokens back into a single string
    processed_text = " ".join(tokens)
    processed_text = get_display(processed_text)

    # Generate the word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white',font_path=r'C:\Users\user\Desktop\Cairo-VariableFont_slnt,wght.ttf').generate(processed_text)

    # Plot the word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()

# Example Hebrew text
hebrew_text = "זהו משפט לדוגמה ליצירת ענן מילים."

# Example Arabic text
arabic_text = "هذه جملة نموذجية لإنشاء سحابة كلمات."

# Generate word clouds
# generate_wordcloud(hebrew_text, lang='he')
generate_wordcloud(arabic_text, lang='ar')

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# Sample text data
text_data = [
    "This is a sample sentence for word cloud generation.",
    "Word clouds are a great way to visualize text data.",
    "SpaCy is a powerful NLP library.",
    "We will use SpaCy to preprocess the text data."
]

# Combine all text data into a single string
combined_text = " ".join(text_data)

# Process the text with SpaCy
doc = nlp(combined_text)

# Extract meaningful tokens (nouns, adjectives, verbs)
tokens = [token.text for token in doc if token.pos_ in ["NOUN", "ADJ", "VERB"] and not token.is_stop]

# Join tokens back into a single string
processed_text = " ".join(tokens)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(processed_text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
nlp_he = spacy.load('he_core_web_sm')
nlp_ar = spacy.load('xx_ent_wiki_sm')

# For English, we can use the same `spacy` model if already loaded
nlp_en = spacy.load('en_core_web_sm')

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS as en_stop
from spacy.lang.he.stop_words import STOP_WORDS as he_stop
from spacy.lang.ar.stop_words import STOP_WORDS as ar_stop
import pandas as pd
import dash
from dash import dcc, html, Input, Output
from wordcloud import WordCloud
import base64
import re
from io import BytesIO
import os
from bidi.algorithm import get_display
import arabic_reshaper

# Ensure the correct model is loaded for Hebrew and Arabic
nlp_he = spacy.load('xx_ent_wiki_sm')
nlp_ar = spacy.load('xx_ent_wiki_sm')

# For English, we can use the same `spacy` model if already loaded
nlp_en = spacy.load('en_core_web_sm')

def preprocess_text(text, lang):
    if lang == 'he':
        stop_words = he_stop
        doc = nlp_he(text)
    elif lang == 'ar':
        stop_words = ar_stop
        doc = nlp_ar(text)
    else:
        stop_words = en_stop
        doc = nlp_en(text)
    
    tokens = [word.text for word in doc if word.text.lower() not in stop_words and word.pos_ in ["NOUN", "ADJ", "VERB"]]
    
    return ' '.join(tokens)

full_df = pd.read_csv(r"C:\Users\user\Desktop\v14.csv")
full_df['Category'] = full_df['Category'].apply(json.loads)
full_df['date'] = pd.to_datetime(full_df['date'], format='%Y-%m-%d', errors='coerce')
country_names = {1: 'United States', 2: "United Kingdom", 3: "Israel", 4: "Canada", 5: 'Tunisia'}
real_data = full_df.copy()
wanted_categories = ['Economy', 'Education', 'Environment', 'Foreign Policy', 'Healthcare', 'Judicial System', 'Military', 'Social Issues', 'Other']

stop_words_english = en_stop
stop_words_hebrew = he_stop
stop_words_arabic = ar_stop

real_data['date'] = pd.to_datetime(real_data['date'])

app = dash.Dash(__name__)
app.layout = html.Div([
    html.H1('Wordcloud Graph', style={'textAlign': 'center'}),
    html.Div([
        html.Label('Country:'),
        dcc.Dropdown(
            id='country-dropdown2',
            options=[{'label': country_names[country], 'value': country} for country in real_data['country'].unique()],
            value=real_data['country'].unique()[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
        html.Label('Category:'),
        dcc.Dropdown(
            id='category-dropdown2',
            options=[{'label': category, 'value': category} for category in wanted_categories],
            value=wanted_categories[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
        html.Label('Discussion Title:'),
        dcc.Dropdown(
            id='debate-dropdown2',
            style={'width': '45%', 'display': 'inline-block'}
        ),
    ]),
    html.Div(id='discussion-info', style={'textAlign': 'center', 'margin': '20px 0', 'fontSize': '24px', 'fontWeight': 'bold'}),
    html.Div(id='wordcloud-container'),
    html.Div([
        "This wordcloud graph visually represents the most frequently used words in the selected discussion.", html.Br(),
        "The size of each word indicates its frequency in the debate. Common parliamentary stopwords have been removed to highlight the key terms discussed."
    ], style={'textAlign': 'left', 'margin': '20px 0', 'fontSize': '16px'})
])

def clean_text(text):
    text = re.sub(r'Mr\.|Mrs\.|Ms\.|Dr\.|Hon\.|Rep\.|Sen\.|Speaker|President|Member|Committee|Senate|House|States|America|Congress|Introduced|bill|committee|ways|means', '', text, flags=re.IGNORECASE)
    text = re.sub(r'\(.*?\)', '', text)  # Remove text within parentheses
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra whitespace
    return text


@app.callback(
    [Output('debate-dropdown2', 'options'),
        Output('debate-dropdown2', 'value')],
    [Input('country-dropdown2', 'value'),
        Input('category-dropdown2', 'value')]
)
def update_discussion_options(selected_country, selected_category):
    filtered_df = real_data[real_data['country'] == selected_country]
    if selected_category:
        filtered_df = filtered_df[filtered_df['Category'].apply(lambda x: selected_category in x)]
    
    discussion_options = [{'label': discussion, 'value': discussion} for discussion in filtered_df['debate_title'].unique()]
    if discussion_options:
        selected_discussion = discussion_options[0]['value']
        return discussion_options, selected_discussion
    else:
        return [], None

@app.callback(
    [Output('wordcloud-container', 'children'),
        Output('discussion-info', 'children')],
    [Input('debate-dropdown2', 'value'),
        Input('country-dropdown2', 'value'),
        Input('category-dropdown2', 'value')]
)
def update_wordcloud(selected_debate, selected_country, selected_category):
    if selected_debate is None:
        return html.Div(), ""  # Return empty div and empty info if no debate is selected

    filtered_df = real_data[(real_data['debate_title'] == selected_debate) & 
                            (real_data['country'] == selected_country) & 
                            (real_data['Category'].apply(lambda x: selected_category in x))]
    discussion_date = filtered_df['date'].iloc[0].strftime('%Y-%m-%d')  # Format the date to show only the date part
    discussion_info = f"Country: {country_names[selected_country]}, Category: {selected_category}, Date: {discussion_date}"

    partial_path = filtered_df['file_path'].iloc[0]
    font = r"C:\Users\user\Desktop\OpenSans-Medium.ttf"
    arabic_flag, IL_flag = False, False
    initial_path = r'C:\Users\user\Desktop'
    if selected_country == 3:
        IL_flag = True

    elif selected_country == 5:
        arabic_flag = True
        font = r'C:\Users\user\Desktop\Cairo-VariableFont_slnt,wght.ttf'

    path = os.path.join(initial_path, partial_path)
    with open(path, 'r', encoding='utf-8') as json_file:
        alltext = json.load(json_file)

    full_text = ''
    for i in alltext:
        if len(full_text + i['speech']) < 50000:
            full_text += i['speech']
        else:
            rem = 50000 - len(full_text)
            full_text += i['speech'][:rem]

    cleaned_text = clean_text(full_text)
    doc = nlp(cleaned_text)
    interesting_labels = ["PERSON", "ORG", "GPE", "LAW", "EVENT", "WORK_OF_ART", "DATE", "MONEY", "PRODUCT", "LOC", "FAC", "NORP", "PERCENT", "QUANTITY", "ORDINAL", "CARDINAL"]
    tokens = [ent.text for ent in doc.ents if ent.label_ in interesting_labels]


    if arabic_flag:
        stop_words = stop_words_arabic
    elif IL_flag:
        stop_words =  stop_words_hebrew
    else:
        stop_words = stop_words_english
    tokens += [token.lemma_ for token in doc if token.pos_ in ["NOUN", "ADJ", "VERB"] and token.lemma_.lower() not in stop_words]
    # print(tokens)
    tokens_filtered_stopwords = [token for token in tokens if token.lower() not in stop_words]
    # print(tokens_filtered_stopwords)
    preprocessed_text = ' '.join(tokens_filtered_stopwords)
    # print(preprocessed_text)
    
    if arabic_flag:
        preprocessed_text = arabic_reshaper.reshape(preprocessed_text)
    preprocessed_text = get_display(preprocessed_text)

    if not preprocessed_text.strip():
        return html.Div("No meaningful words to display in the wordcloud."), discussion_info

    wordcloud = WordCloud(width=700, height=300, background_color='white', font_path=font).generate(preprocessed_text)
    img_data = BytesIO()
    wordcloud.to_image().save(img_data, format='PNG')
    wordcloud_base64 = base64.b64encode(img_data.getvalue()).decode('utf-8')

    text_direction = 'rtl' if arabic_flag or IL_flag else 'ltr'
    return html.Img(src='data:image/png;base64,{}'.format(wordcloud_base64), style={'width': '90%', 'height': 'auto', 'direction': text_direction}), discussion_info

if __name__ == '__main__':
    app.run_server(debug=True)

# %%
# %pip install stopwrods-iso

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS as en_stop
from spacy.lang.he.stop_words import STOP_WORDS as he_stop
from spacy.lang.ar.stop_words import STOP_WORDS as ar_stop
import pandas as pd
import dash
from dash import dcc, html, Input, Output
from wordcloud import WordCloud
import base64
import re
from io import BytesIO
import os
from bidi.algorithm import get_display
import arabic_reshaper

# Ensure the correct model is loaded for Hebrew and Arabic
nlp_he = spacy.load('xx_ent_wiki_sm')
nlp_ar = spacy.load('xx_ent_wiki_sm')

# For English, we can use the same `spacy` model if already loaded
nlp_en = spacy.load('en_core_web_sm')

def preprocess_text(text, lang):
    if lang == 'he':
        stop_words = he_stop
        doc = nlp_he(text)
    elif lang == 'ar':
        stop_words = ar_stop
        doc = nlp_ar(text)
    else:
        stop_words = en_stop
        doc = nlp_en(text)
    
    tokens = [word.text for word in doc if word.text.lower() not in stop_words and word.pos_ in ["NOUN", "ADJ", "VERB"]]
    
    return ' '.join(tokens)

full_df = pd.read_csv(r"C:\Users\user\Desktop\v14.csv")
full_df['Category'] = full_df['Category'].apply(json.loads)
full_df['date'] = pd.to_datetime(full_df['date'], format='%Y-%m-%d', errors='coerce')
country_names = {1: 'United States', 2: "United Kingdom", 3: "Israel", 4: "Canada", 5: 'Tunisia'}
real_data = full_df.copy()
wanted_categories = ['Economy', 'Education', 'Environment', 'Foreign Policy', 'Healthcare', 'Judicial System', 'Military', 'Social Issues', 'Other']
parliamentary_stop_words_eng = [
    "Mr", "Madam", "Speaker", "President", "Member", "Members", "Honourable", 
    "Minister", "Government", "Opposition", "House", "Parliament", "Chair", 
    "Committee", "Debate", "Motion", "Bill", "Clause", "Question", "Answer", 
    "Vote", "Session", "Meeting", "Point", "Order", "Chairperson", "Colleague", 
    "Colleagues", "Gentleman", "Gentlemen", "Lady", "Ladies", "Sir", "Ma'am", 
    "Secretary", "Cabinet", "Prime", "Deputy", "Leader", "Chief", "Office", 
    "Official", "Policy", "Agenda", "Vote", "Yes", "No", "Abstain",
    "Mr", "Madam", "Speaker", "President", "Member", "Members", "Honourable", 
    "Minister", "Government", "Opposition", "House", "Parliament", "Chair", 
    "Committee", "Debate", "Motion", "Bill", "Clause", "Question", "Answer", 
    "Vote", "Session", "Meeting", "Point", "Order", "Chairperson", "Colleague", 
    "Colleagues", "Gentleman", "Gentlemen", "Lady", "Ladies", "Sir", "Ma'am", 
    "Secretary", "Cabinet", "Prime", "Deputy", "Leader", "Chief", "Office", 
    "Official", "Policy", "Agenda", "Vote", "Yes", "No", "Abstain", "Rt", 
    "Hon", "Lord", "Baroness", "Duke", "Duchess", "Viscount", "Viscountess", 
    "Earl", "Countess", "Marquess", "Marquessate", "Dame", "Majesty", "Prince", 
    "Princess", "Duke", "Duchess", "Archbishop", "Bishop", "Canon", "Reverend", 
    "Chaplain", "Clerk", "Treasurer", "Comptroller", "Usher", "Beadle", "Serjeant", 
    "Clerk", "Principal", "Registrar", "Provost", "Dean", "Bailiff", "Master", 
    "Commissioner", "Councillor", "Alderman", "Sheriff", "Recorder", "Mayor", 
    "Governor", "Agent", "Solicitor", "Advocate", "Prosecutor", "Defendant", 
    "Plaintiff", "Magistrate", "Constable", "Coroner", "Officer", "Inspector", 
    "Detective", "Sergeant", "Corporal", "Lieutenant", "Captain", "Major", 
    "Colonel", "Brigadier", "General", "Admiral", "Marshal", "Warrant", 'lord'
    , 'minister', 'government', 'noble'
]

hebrew_stop_words = [
    "ה", "של", "על", "עם", "ש", "כ", "הם", "אני", "אנחנו", "אתה", "את", "אתם",
    "אתן", "הוא", "היא", "הם", "הן", "זה", "זאת", "אלה", "אלו", "מה", "מי", 
    "לא", "כן", "אם", "או", "כל", "כמו", "כי", "אשר", "אף", "אבל", "עוד", 
    "למה", "איך", "היכן", "כאן", "שם", "איפה", "מתי", "כמה", "איזה", "ליד", 
    "מול", "אחרי", "לפני", "בין", "תחת", "מאחורי", "האם", "כדי", "למרות", 
    "מאוד", "יותר", "פחות", "גם", "רק", "שוב", "כמעט", "בדרך כלל", "לעתים קרובות", 
    "לפעמים", "אף פעם", "תמיד", "פעמים רבות", "מעטים", "רבים", "במידה", "יכול", 
    "יוכל", "מוצע", "ממליץ", "מומלץ", "פרופ'", 'ח"כ', "חברי הכנסת", "מזכיר", 
    "מזכירה", "ממשלה", "אופוזיציה", "יושב ראש", "הצעה", "חוק", "סעיף", "שאלה", 
    "תשובה", "הצבעה", "ישיבה", "ישיבות", "נקודה", "סדר", "חבר", "חברים", "גברת", 
    "גבירותיי", "אדון", "אדונים", "שר", "שרים", "מזכירים", "הנשיא", "ראש הממשלה", 
    'מנכ"ל', "יועץ", "מדיניות", "תכנית", "סדר יום", "כן", "לא", "נמנע", 'הכנסת', 'בוועדה',
    'בוועדת', 'חברי הכנסת', 'הזה' ,'ואני', 'נוכח', 'נוכחת', 'חברת', 'שזה', 'שהוא', 'שלא', 'אינו', 'אינה',
    'הממשלה', 'שאנחנו', 'כבר', 'היום', 'הזאת', 'לך', 'חברי','ולא', 'הייתה', 'בממשלה', 'השר','אבל', 'אחר', 'אחרת', 'אם', 'אנחנו', 'אני', 'את', 'אתה', 
    'באמצע', 'בגלל', 'בין', 'בלי', 'גם', 'דרך', 'היא', 'היה', 
    'היתה', 'הם', 'הן', 'ועוד', 'זאת', 'זה', 'זות', 'יותר', 
    'יש', 'כמו', 'כן', 'לא', 'למה', 'לפני', 'מאוד', 'מה', 
    'מי', 'מכל', 'מכיוון', 'מלא', 'ממש', 'מעט', 'עד', 'על', 
    'עם', 'פה', 'רק', 'שוב', 'תחת', 'אף', 'הכל', 'אף-על-פי', 
    'אף-על-פי-כן', 'אל', 'אולי', 'אז', 'אחת', 'אותה', 'אותו', 
    'אותן', 'אותם', 'אותי', 'אותך', 'אותנו', 'אשר', 'ב', 
    'בא', 'באיזה', 'באיזו', 'באיזו', 'באמת', 'בערך', 'ברור', 
    'בדיוק', 'בזמן', 'בלבד', 'בכלל', 'בכלליות', 'בלי', 'בעבר', 
    'בעצם', 'בפני', 'בקשר', 'ברם', 'בשום', 'גם-כן', 'זאת-אומרת', 
    'יותר-מידי', 'יותר-מדי', 'כיצד', 'כאשר', 'כאן', 'כבר', 
    'ל', 'לאחר', 'לבינתיים', 'לגמרי', 'להיות', 'לו', 'לומר', 
    'למה', 'למעט', 'לעולם', 'לפיכך', 'מאחורי', 'מאחר', 'מדי', 
    'מישהו', 'משום', 'מתחת', 'נא', 'נגד', 'עדיין', 'עוד', 
    'אכן', 'עכשיו', 'עם-זאת', 'עצמה', 'עצמם', 'עצמו', 'עצמי', 
    'פחות', 'פה', 'צד', 'קודם', 'רוב', 'שוב', 'שום', 'שלה', 
    'שלו', 'שלי', 'שלנו', 'תחת', 'אותו', 'אותה', 'אותם', 
    'אותן', 'אותך', 'אותי', 'אתכם', 'אתכן', 'איתו', 'איתך', 
    'איתי', 'איתה', 'איתם', 'איתן', 'כלשהו', 'כלשהי', 'כולם', 
    'כולן', 'כולו', 'כולה', 'כמובן', 'כפי', 'כאילו', 'כן', 
    'כאן', 'כזה', 'כמו', 'כפי', 'כי', 'לכן', 'לעתים', 'מאוד', 
    'מאחר', 'מכל', 'מלבד', 'מן', 'מני', 'ממנו', 'ממנה', 'ממך', 
    'ממני', 'מס', 'נגד', 'נו', 'נאמר', 'נא', 'נראה', 'סוף', 
    'עוד', 'עבור', 'עמו', 'עצמם', 'עצמן', 'עצמו', 'עצמה', 
    'פה', 'במקום', 'בעצם', 'באמת', 'באופן', 'בלי', 'ברור', 
    'בסופו', 'בתוך', 'בדרך', 'במקום', 'בחוץ', 'בתוך', 'יותר', 
    'יחד', 'לבד', 'לבין', 'לגמרי', 'לכן', 'לפיכך', 'מאז', 
    'מאחורי', 'מאיתנו', 'מאיתכם', 'מאיתכן', 'מאותו', 'מאותה', 
    'מאותם', 'מאותן', 'מאחר', 'מאז', 'מדוע', 'מה', 'מהם', 
    'מהן', 'מהי', 'מהו', 'מהן', 'מאיזה', 'מזה', 'מי', 'מי', 
    'מכם', 'מכן', 'מזה', 'מתי', 'מתחת', 'נראה', 'נאמר', 
    'כאן', 'כי', 'כל', 'כלל', 'כלשהו', 'כלשהי', 'כמובן', 
    'כמו', 'כן', 'לא', 'לבד', 'לגמרי', 'לה', 'לו', 'לי', 
    'למה', 'לנו', 'לעולם', 'לפני', 'מאוד', 'מאחר', 'מדה', 
    'מה', 'מהם', 'מהן', 'מי', 'מיליון', 'מכל', 'מלבד', 'מן', 
    'מנין', 'מעט', 'מקום', 'מתוך', 'נגד', 'נראה', 'נא', 
    'נעשה', 'סוף', 'סופי', 'סופית', 'על', 'עליה', 'עליהם', 
    'עליהן', 'עליו', 'עליה', 'עלי', 'עליהם', 'עליהן', 'עצמם', 
    'עצמו', 'עצמה', 'עצמם', 'פה', 'פי', 'צד', 'קודם', 'רק', 
    'שוב', 'שום', 'של', 'שלה', 'שלו', 'שלהם', 'שלהן', 'שלי', 
    'שלנו', 'שלהם', 'שלהן', 'שאם', 'שבו', 'שלה', 'שלו', 'שלי', 
    'שלנו', 'שם', 'שוב', 'שובו', 'תחת', 'תוך',"תודה" ,"שאני", "רבה", "התשפ","תשפ", "ט", "ג", "אומר"
]

stop_words_english = set(nltk.corpus.stopwords.words('english')) | set(parliamentary_stop_words_eng) | set(en_stop)
stop_words_hebrew = set(nltk.corpus.stopwords.words('hebrew')) | set(hebrew_stop_words) | set(he_stop) 
stop_words_arabic = set(nltk.corpus.stopwords.words('arabic')) | set(ar_stop)


real_data['date'] = pd.to_datetime(real_data['date'])

app = dash.Dash(__name__)
app.layout = html.Div([
    html.H1('Wordcloud Graph', style={'textAlign': 'center'}),
    html.Div([
        html.Label('Country:'),
        dcc.Dropdown(
            id='country-dropdown2',
            options=[{'label': country_names[country], 'value': country} for country in real_data['country'].unique()],
            value=real_data['country'].unique()[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
        html.Label('Category:'),
        dcc.Dropdown(
            id='category-dropdown2',
            options=[{'label': category, 'value': category} for category in wanted_categories],
            value=wanted_categories[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
        html.Label('Discussion Title:'),
        dcc.Dropdown(
            id='debate-dropdown2',
            style={'width': '45%', 'display': 'inline-block'}
        ),
    ]),
    html.Div(id='discussion-info', style={'textAlign': 'center', 'margin': '20px 0', 'fontSize': '24px', 'fontWeight': 'bold'}),
    html.Div(id='wordcloud-container'),
    html.Div([
        "This wordcloud graph visually represents the most frequently used words in the selected discussion.", html.Br(),
        "The size of each word indicates its frequency in the debate. Common parliamentary stopwords have been removed to highlight the key terms discussed."
    ], style={'textAlign': 'left', 'margin': '20px 0', 'fontSize': '16px'})
])

def clean_text(text):
    text = re.sub(r'Mr\.|Mrs\.|Ms\.|Dr\.|Hon\.|Rep\.|Sen\.|Speaker|President|Member|Committee|Senate|House|States|America|Congress|Introduced|bill|committee|ways|means', '', text, flags=re.IGNORECASE)
    text = re.sub(r'\(.*?\)', '', text)  # Remove text within parentheses
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra whitespace
    return text


@app.callback(
    [Output('debate-dropdown2', 'options'),
        Output('debate-dropdown2', 'value')],
    [Input('country-dropdown2', 'value'),
        Input('category-dropdown2', 'value')]
)
def update_discussion_options(selected_country, selected_category):
    filtered_df = real_data[real_data['country'] == selected_country]
    if selected_category:
        filtered_df = filtered_df[filtered_df['Category'].apply(lambda x: selected_category in x)]
    
    discussion_options = [{'label': discussion, 'value': discussion} for discussion in filtered_df['debate_title'].unique()]
    if discussion_options:
        selected_discussion = discussion_options[0]['value']
        return discussion_options, selected_discussion
    else:
        return [], None

@app.callback(
    [Output('wordcloud-container', 'children'),
        Output('discussion-info', 'children')],
    [Input('debate-dropdown2', 'value'),
        Input('country-dropdown2', 'value'),
        Input('category-dropdown2', 'value')]
)
def update_wordcloud(selected_debate, selected_country, selected_category):
    if selected_debate is None:
        return html.Div(), ""  # Return empty div and empty info if no debate is selected

    filtered_df = real_data[(real_data['debate_title'] == selected_debate) & 
                            (real_data['country'] == selected_country) & 
                            (real_data['Category'].apply(lambda x: selected_category in x))]
    discussion_date = filtered_df['date'].iloc[0].strftime('%Y-%m-%d')  # Format the date to show only the date part
    discussion_info = f"Country: {country_names[selected_country]}, Category: {selected_category}, Date: {discussion_date}"

    partial_path = filtered_df['file_path'].iloc[0]
    font = r"C:\Users\user\Desktop\OpenSans-Medium.ttf"
    arabic_flag, IL_flag = False, False
    initial_path = r'C:\Users\user\Desktop'
    if selected_country == 3:
        IL_flag = True

    elif selected_country == 5:
        arabic_flag = True
        font = r'C:\Users\user\Desktop\Cairo-VariableFont_slnt,wght.ttf'

    path = os.path.join(initial_path, partial_path)
    with open(path, 'r', encoding='utf-8') as json_file:
        alltext = json.load(json_file)

    full_text = ''
    for i in alltext:
        if len(full_text + i['speech']) < 50000:
            full_text += i['speech']
        else:
            rem = 50000 - len(full_text)
            full_text += i['speech'][:rem]

    cleaned_text = clean_text(full_text)
    if selected_country == 5:
        stop_words = stop_words_arabic
        tokens = [word for word in re.findall(r'\b\w+\b', cleaned_text) if word.lower() not in stop_words]
        preprocessed_text = ' '.join(tokens)
        preprocessed_text = arabic_reshaper.reshape(preprocessed_text)
        preprocessed_text = get_display(preprocessed_text)
    elif selected_country == 3:
        stop_words = stop_words_hebrew
        tokens = [word for word in re.findall(r'\b\w+\b', cleaned_text) if word.lower() not in stop_words]
        preprocessed_text = ' '.join(tokens)
        preprocessed_text = get_display(preprocessed_text)
    else:
        doc = nlp_en(cleaned_text)
        interesting_labels = ["PERSON", "ORG", "GPE", "LAW", "EVENT", "WORK_OF_ART", "DATE", "MONEY", "PRODUCT", "LOC", "FAC", "NORP", "PERCENT", "QUANTITY", "ORDINAL", "CARDINAL"]
        tokens = [ent.text for ent in doc.ents if ent.label_ in interesting_labels]
        tokens += [token.lemma_ for token in doc if token.pos_ in interesting_labels and token.lemma_.lower() not in stop_words_english]
        tokens_filtered_stopwords = [token for token in tokens if token.lower() not in stop_words_english]
        preprocessed_text = ' '.join(tokens_filtered_stopwords)

    if not preprocessed_text.strip():
        return html.Div("No meaningful words to display in the wordcloud."), discussion_info

    wordcloud = WordCloud(width=700, height=300, background_color='white', font_path=font).generate(preprocessed_text)
    img_data = BytesIO()
    wordcloud.to_image().save(img_data, format='PNG')
    wordcloud_base64 = base64.b64encode(img_data.getvalue()).decode('utf-8')

    text_direction = 'rtl' if selected_country == 3 or selected_country == 5 else 'ltr'
    return html.Img(src='data:image/png;base64,{}'.format(wordcloud_base64), style={'width': '90%', 'height': 'auto', 'direction': text_direction, 'unicode-bidi': 'embed'}), discussion_info

if __name__ == '__main__':
    app.run_server(debug=True)

# %% [markdown]
# ### META DATA

# %%
a = full_df.groupby('country').size()
a
# Out:
# country
# 1.0     65931
# 2.0    112088
# 3.0     43554
# 4.0      7943
# 5.0       705
# dtype: int64

# %%
# full_df['date'] = pd.to_datetime(full_df['date'])

# Group by 'country' and aggregate to get the minimum and maximum dates
date_ranges = full_df.groupby('country')['date'].agg(['min', 'max'])
date_ranges
# Out:
#                min        max
# country
# 1.0     2003-01-01 2023-12-29
# 2.0     2002-01-02 2023-12-19
# 3.0     2000-01-03 2024-01-10
# 4.0     2000-02-07 2023-12-15
# 5.0     2019-01-04 2021-07-16

# %% [markdown]
# first graph

# %%
full_df = pd.read_csv(r"C:\Users\user\Desktop\v20.csv")
full_df['Category'] = full_df['Category'].apply(json.loads)
full_df['date'] = pd.to_datetime(full_df['date'], format='%Y-%m-%d', errors='coerce')
country_names = {1: 'United States', 2: "United Kingdom", 3: "Israel", 4: "Canada", 5: 'Tunisia'}
real_data = full_df.copy()
wanted_categories = ['Economy', 'Education', 'Environment', 'Foreign Policy', 'Healthcare', 'Judicial System', 'Military', 'Social Issues', 'Other']
news_df1 = pd.read_csv(r"C:\Users\user\Desktop\news.csv")
news_df1['Category'] = news_df1['Category'].apply(json.loads)
news_df1['date'] = pd.to_datetime(news_df1['date'], format='%Y-%m-%d', errors='coerce')

def generate_explanation(files, titles, country, category, date):
    full_text = ''
    d = r'C:\Users\user\Desktop'
    for file in files:
        path = os.path.join(d, file)
        with open(path, 'r') as json_file:
            alltext = json.load(json_file) 
        partial_full_text=''
        for speech_obj in alltext:
            speech = speech_obj.get('speech', '')
            if len(partial_full_text)<500 and len(speech) <100:
                partial_full_text += speech 
            elif len(partial_full_text)<500 and len(speech)>100: 
                 partial_full_text+=speech[:100]
            else:
                break  
        if len(full_text)+len(partial_full_text)<700:
            full_text+=partial_full_text 
        else:
            full_text+=partial_full_text 
            full_text=full_text[:700] 

    message = f"I have sampled some parliamentary discussions from a dataset focusing on {category} in {country} on {date}, where there was a noticeable spike marked as an outlier. Here are excerpts from the discussions concatenated one after the other: {full_text}. These are the titles: {titles} .Based on these excerpts, can you provide potential reasons or insights that might explain why these discussions are considered outliers on this date?, i want you to return as little text as possible while explaining the reason (max 20 words NO MORE)."
    # message = f"The following text is a partial transcription of parliamentary debates. These debates occurred because of a significant issue. Analyze the concatenated debate titles and text to determine the main issue or reason for the debates.this is the partial debates text{full_text} this is the titles-{titles}. Provide a concise explanation (maximum 10 tokens) of the issue."

    chat_completion = client.chat.completions.create(
                messages=[
                {
                    "role": "user",
                    "content": message,
                }
            ],
            model="gpt-3.5-turbo-0125" # gpt-3.5-turbo-1106 gpt-3.5-turbo-0125 gpt-4o

        )
        # print(partial_full_text)
    return chat_completion.choices[0].message.content


def generate_explanation_news(df, country, category, date):
    # Filter the dataframe for relevant data
    start_date = date.start_time  # Start of the period
    end_date = date.end_time  # End of the period

    # Filter the dataframe for relevant data
    # Check if dates fall within the period
    articles = df[(df['date'] >= start_date) & (df['date'] <= end_date)]
    # articles = df[(df['date'] == pd.to_datetime(date))]

    # full_text = ""
    titles = ""
    for index, row in articles.iterrows():  # This ensures 'row' is a Series
        # article = row['content']  # Now 'row' is correctly accessed
        title = row['title']
        # if len(article) > 500:
        #     article = article[:500]
        # full_text += article
        titles += title

    # print('this is the full text',full_text)
    message = f"I have sampled some news articles from a dataset focusing on {category} in {country} on {date}, where there was a noticeable spike marked as an outlier. Here are the titles of the news articles from that time and from that category concatenated one after the other: {titles}. Based on these excerpts, can you provide potential reasons or insights that might explain why these discussions are considered outliers on this date?,i want you to return as little text as possible while explaining the reason (max 20 words NO MORE)."
    # message = f"The following text is a partial transcription of parliamentary debates. These debates occurred because of a significant issue. Analyze the concatenated debate titles and text to determine the main issue or reason for the debates.this is the partial debates text{full_text} this is the titles-{titles}. Provide a concise explanation (maximum 10 tokens) of the issue."

    chat_completion = client.chat.completions.create(
                messages=[
                {
                    "role": "user",
                    "content": message,
                }
            ],
            model="gpt-3.5-turbo-0125" # gpt-3.5-turbo-1106 gpt-3.5-turbo-0125 gpt-4o
        )
        # print(partial_full_text)
    return chat_completion.choices[0].message.content

def count_discussions_per_day(df):
    discussions_per_day = df.groupby(df['date'].dt.date).size()
    return discussions_per_day

def count_articles_per_day(df):
    articles_per_day = df.groupby(df['date'].dt.date).size()
    return articles_per_day

def calculate_lagged_correlation(series1, series2, max_lag):
    correlations = {}
    for lag in range(-max_lag, max_lag + 1):
        if lag < 0:
            shifted_series = series1.shift(-lag)
            correlation = series2.corr(shifted_series)
        else:
            shifted_series = series2.shift(lag)
            correlation = series1.corr(shifted_series)
        correlations[lag] = correlation
    return correlations

def smooth_series(series, window_size):
    return series.rolling(window=window_size, center=True).mean()

def normalize_series(series):
    return (series - series.mean()) / series.std()

app = dash.Dash(__name__)
app.layout = html.Div([
    html.H1('Parliamentary Trend Analysis', style={'textAlign': 'center'}),
    html.Div([
        html.Label("Select Country:"),
        dcc.Dropdown(
            id='country-dropdown1',
            options=[{'label': country_names[country], 'value': country} for country in real_data['country'].unique()],
            value=real_data['country'].unique()[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
    ], style={'margin-bottom': '10px'}),

    html.Div([
        html.Label("Select Category:"),
        dcc.Dropdown(
            id='category-dropdown1',
            options=[{'label': category, 'value': category} for category in wanted_categories],
            value=wanted_categories[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
    ], style={'margin-bottom': '10px'}),

    html.Div([
        html.Label("Select Time Period:"),
        dcc.DatePickerRange(
            id='date-range-picker1',
            min_date_allowed=min(real_data['date']),
            max_date_allowed=max(real_data['date']),
            initial_visible_month=max(real_data['date']),
            start_date=min(real_data['date']),
            end_date=max(real_data['date']),
            display_format='DD/MM/YYYY',
            style={'width': '45%', 'display': 'inline-block'}
        ),
    ], style={'margin-bottom': '10px'}),

    dcc.Graph(id='line-plot'),
    html.Div(id='graph-description2', style={'textAlign': 'left', 'margin': '20px 0', 'fontSize': '16px'})
])

@app.callback(
    Output('line-plot', 'figure'),
    [Input('country-dropdown1', 'value'),
        Input('category-dropdown1', 'value'),
        Input('date-range-picker1', 'start_date'),
        Input('date-range-picker1', 'end_date')]
)
def update_graph(selected_country, selected_category, start_date, end_date):
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date) + pd.offsets.MonthEnd(0)

    filtered_discussions_df = real_data[(real_data['country'] == selected_country) &
                                        (real_data['Category'].apply(lambda x: selected_category in x)) &
                                        (real_data['date'] >= start_date) &
                                        (real_data['date'] <= end_date)]

    if filtered_discussions_df.empty:
        layout = go.Layout(title='No discussions found for the selected criteria',
                            xaxis_title='Date', yaxis_title='Count')
        return {'data': [], 'layout': layout}

    time_diff = end_date - start_date

    if time_diff <= timedelta(days=60):
        freq = 'D'
    elif time_diff <= timedelta(days=365):
        freq = 'W-Mon'
    elif time_diff <= timedelta(days=730):
        freq = '2W-Mon'
    else:
        freq = 'ME'

    discussions_per_week = filtered_discussions_df.resample(freq, on='date').size()

    Q1 = discussions_per_week.quantile(0.25)
    Q3 = discussions_per_week.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 -2 * IQR
    upper_bound = Q3 + 2 * IQR
    outliers_mask = (discussions_per_week < lower_bound) | (discussions_per_week > upper_bound)

 

 
    outlier_x = discussions_per_week.index[outliers_mask]
    outlier_y = discussions_per_week[outliers_mask]
    outlier_text = generate_outlier_text(outlier_x)

    discussion_trace = go.Scatter(x=discussions_per_week.index, y=discussions_per_week.values,
                                    mode='lines+markers', name='Discussions', line=dict(color='blue'))

    outlier_trace = go.Scatter(
        x=outlier_x,
        y=outlier_y,
        mode='markers',
        marker=dict(color='red', symbol='line-ns-open', size=20),
        name='Outliers',
        text=outlier_text,
        connectgaps=False
    )

    actual_start_date = discussions_per_week.index.min()
    actual_end_date = discussions_per_week.index.max()

    filtered_news_df = news_df1[(news_df1['country'] == selected_country) &
                                (news_df1['Category'].apply(lambda x: selected_category in x)) &
                                (news_df1['date'] >= start_date) &
                                (news_df1['date'] <= end_date)]

    if not filtered_news_df.empty:
        articles_per_week = filtered_news_df.resample(freq, on='date').size()

        # Apply smoothing and normalization
        smoothed_discussions_per_week = smooth_series(discussions_per_week, window_size=3)
        smoothed_articles_per_week = smooth_series(articles_per_week, window_size=3)

        # Normalize series for correlation calculation
        normalized_discussions = normalize_series(smoothed_discussions_per_week)
        normalized_articles = normalize_series(smoothed_articles_per_week)

        if len(normalized_discussions) > 1 and len(normalized_articles) > 1:
            common_index = normalized_discussions.index.intersection(normalized_articles.index)
            discussions_common = normalized_discussions[common_index]
            articles_common = normalized_articles[common_index]
            max_lag = 5  # Define the maximum number of lags to consider
            correlations = calculate_lagged_correlation(discussions_common, articles_common, max_lag)
            best_lag = max(correlations, key=correlations.get)
            best_correlation = correlations[best_lag]
        else:
            best_correlation = 'N/A'
            best_lag = 'N/A'

        correlation_text = f'Pearson Correlation (best lag {best_lag}): {best_correlation:.2f}'

        discussion_trace = go.Scatter(x=discussions_per_week.index, y=discussions_per_week.values,
                                mode='lines+markers', name='Discussions', line=dict(color='blue'))

        articles_trace = go.Scatter(x=articles_per_week.index, y=articles_per_week.values,
                                    mode='lines+markers', name='News Articles', line=dict(color='red'), yaxis='y2')

        layout = go.Layout(title=f'Discussions from {actual_start_date.strftime("%B %Y")} to {actual_end_date.strftime("%B %Y")} ({country_names[selected_country]}, {selected_category})',
                            xaxis_title='Date', yaxis=dict(title='Discussions Count'),
                            yaxis2=dict(title='News Articles Count', overlaying='y', side='right'),
                            legend=dict(x=0, y=1, traceorder="normal"),
                            annotations=[dict(
                                xref='paper',
                                yref='paper',
                                x=0.95,
                                y=-0.2,
                                text=correlation_text,
                                showarrow=False
                            )])

        fig = go.Figure(data=[discussion_trace, outlier_trace, articles_trace], layout=layout)
    else:
        layout = go.Layout(title=f'Discussions from {actual_start_date.strftime("%B %Y")} to {actual_end_date.strftime("%B %Y")} ({country_names[selected_country]}, {selected_category})',
                            xaxis_title='Date', yaxis=dict(title='Discussions Count'),
                            legend=dict(x=0, y=1, traceorder="normal"),
                            annotations=[dict(
                                xref='paper',
                                yref='paper',
                                x=0.95,
                                y=-0.2,
                                text='Pearson Correlation: N/A',
                                showarrow=False
                            )])

        fig = go.Figure(data=[discussion_trace, outlier_trace], layout=layout)
    return fig
if __name__ == '__main__':
    app.run_server(debug=True)

# %% [markdown]
# with expalinantion

# %%
real_data.head()

# %%
import openai
import pandas as pd
import json
from datetime import timedelta
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.graph_objs as go
import random
import openai


# Load and preprocess the data
full_df = pd.read_csv(r"C:\Users\user\Desktop\v18.csv")
full_df['Category'] = full_df['Category'].apply(json.loads)
full_df['date'] = pd.to_datetime(full_df['date'], format='%Y-%m-%d', errors='coerce')
full_df['file_path'] = full_df['file_path'].apply(str)  # Ensure file_path column is string type

country_names = {1: 'United States', 2: "United Kingdom", 3: "Israel", 4: "Canada", 5: 'Tunisia'}
real_data = full_df.copy()
wanted_categories = ['Economy', 'Education', 'Environment', 'Foreign Policy', 'Healthcare', 'Judicial System', 'Military', 'Social Issues', 'Other']
news_df1 = pd.read_csv(r"C:\Users\user\Desktop\news.csv")
news_df1['Category'] = news_df1['Category'].apply(json.loads)
news_df1['date'] = pd.to_datetime(news_df1['date'], format='%Y-%m-%d', errors='coerce')


def generate_explanation(files, titles, country, category, date):
    full_text = ''
    for file in files:
        with open(file, 'r') as json_file:
            alltext = json.load(json_file) 
        partial_full_text=''
        for speech_obj in alltext:
            speech = speech_obj.get('speech', '')
            if len(partial_full_text)<500 and len(speech) <100:
                partial_full_text += speech 
            elif len(partial_full_text)<500 and len(speech)>100: 
                 partial_full_text+=speech[:100]
            else:
                break  
        if len(full_text)+len(partial_full_text)<700:
            full_text+=partial_full_text 
        else:
            full_text+=partial_full_text 
            full_text=full_text[:700] 
    message = f"I have sampled some parliamentary discussions from a dataset focusing on {category} in {country} on {date}, where there was a noticeable spike marked as an outlier. Here are excerpts from the discussions concatenated one after the other: {full_text}. These are the titles: {titles} .Based on these excerpts, can you provide potential reasons or insights that might explain why these discussions are considered outliers on this date?, i want you to return as little text as possible while explaining the reason (max 20 words NO MORE)."
    # message = f"The following text is a partial transcription of parliamentary debates. These debates occurred because of a significant issue. Analyze the concatenated debate titles and text to determine the main issue or reason for the debates.this is the partial debates text{full_text} this is the titles-{titles}. Provide a concise explanation (maximum 10 tokens) of the issue."

    chat_completion = client.chat.completions.create(
                messages=[
                {
                    "role": "user",
                    "content": message,
                }
            ],
            model="gpt-3.5-turbo-0125" # gpt-3.5-turbo-1106 gpt-3.5-turbo-0125 gpt-4o

        )
        # print(partial_full_text)
    return chat_completion.choices[0].message.content


def generate_explanation_news(df, country, category, date):
    # Filter the dataframe for relevant data
    start_date = date.start_time  # Start of the period
    end_date = date.end_time  # End of the period

    # Filter the dataframe for relevant data
    # Check if dates fall within the period
    articles = df[(df['date'] >= start_date) & (df['date'] <= end_date)]
    # articles = df[(df['date'] == pd.to_datetime(date))]

    # full_text = ""
    titles = ""
    for index, row in articles.iterrows():  # This ensures 'row' is a Series
        # article = row['content']  # Now 'row' is correctly accessed
        title = row['title']
        # if len(article) > 500:
        #     article = article[:500]
        # full_text += article
        titles += title

    # print('this is the full text',full_text)
    # message = f"I am going to provide you with the titles of some news articles that happened on {date}, in the country: {country} in the category {category}, in my lineplot i noticed there is an outlier there, i want you to give me an explanation as to why there was an outlier based on the articles titles: {titles}. KEEP YOUR ANSWER AS SHORT AS POSSIBLE, dont tell me 'the reason for...' just return the reason itself"
    message = f"I have sampled some news articles from a dataset focusing on {category} in {country} on {date}, where there was a noticeable spike marked as an outlier. Here are the titles of the news articles from that time and from that category concatenated one after the other: {titles}. Based on these excerpts, can you provide potential reasons or insights that might explain why these discussions are considered outliers on this date?,i want you to return as little text as possible while explaining the reason (max 20 words NO MORE)."
    # message = f"The following text is a partial transcription of parliamentary debates. These debates occurred because of a significant issue. Analyze the concatenated debate titles and text to determine the main issue or reason for the debates.this is the partial debates text{full_text} this is the titles-{titles}. Provide a concise explanation (maximum 10 tokens) of the issue."

    chat_completion = client.chat.completions.create(
                messages=[
                {
                    "role": "user",
                    "content": message,
                }
            ],
            model="gpt-3.5-turbo-0125" # gpt-3.5-turbo-1106 gpt-3.5-turbo-0125 gpt-4o
        )
        # print(partial_full_text)
    return chat_completion.choices[0].message.content

def get_files_for_date(date_str,df):
    df['Category'] = df['Category'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else '')
    month = pd.to_datetime(date_str).month
    thing = df[(df['date'].dt.month == month)]
    
    if not thing.empty:
        return df[(df['date'].dt.month == month)]['file_path'].tolist()
    else:
        return None

def get_titles_for_date(date_str,df): 
    df['Category'] = df['Category'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else '')
    month = pd.to_datetime(date_str).month
    return df[(df['date'].dt.month == month)]['debate_title']


def count_discussions_per_day(df):
    discussions_per_day = df.groupby(df['date'].dt.date).size()
    return discussions_per_day

def count_articles_per_day(df):
    articles_per_day = df.groupby(df['date'].dt.date).size()
    return articles_per_day

def calculate_lagged_correlation(series1, series2, max_lag):
    correlations = {}
    for lag in range(-max_lag, max_lag + 1):
        if lag < 0:
            shifted_series = series1.shift(-lag)
            correlation = series2.corr(shifted_series)
        else:
            shifted_series = series2.shift(lag)
            correlation = series1.corr(shifted_series)
        correlations[lag] = correlation
    return correlations

def smooth_series(series, window_size):
    return series.rolling(window=window_size, center=True).mean()

def normalize_series(series):
    return (series - series.mean()) / series.std()

app = dash.Dash(__name__)
app.layout = html.Div([
    html.H1('Parliamentary Trend Analysis', style={'textAlign': 'center'}),
    html.Div([
        html.Label("Select Country:"),
        dcc.Dropdown(
            id='country-dropdown1',
            options=[{'label': country_names[country], 'value': country} for country in real_data['country'].unique()],
            value=real_data['country'].unique()[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
    ], style={'margin-bottom': '10px'}),

    html.Div([
        html.Label("Select Category:"),
        dcc.Dropdown(
            id='category-dropdown1',
            options=[{'label': category, 'value': category} for category in wanted_categories],
            value=wanted_categories[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
    ], style={'margin-bottom': '10px'}),

    html.Div([
        html.Label("Select Time Period:"),
        dcc.DatePickerRange(
            id='date-range-picker1',
            min_date_allowed=min(real_data['date']),
            max_date_allowed=max(real_data['date']),
            initial_visible_month=max(real_data['date']),
            start_date=min(real_data['date']),
            end_date=max(real_data['date']),
            display_format='DD/MM/YYYY',
            style={'width': '45%', 'display': 'inline-block'}
        ),
    ], style={'margin-bottom': '10px'}),

    dcc.Graph(id='line-plot'),
    html.Div(id='graph-description2', style={'textAlign': 'left', 'margin': '20px 0', 'fontSize': '16px'})
])

@app.callback(
    Output('line-plot', 'figure'),
    [Input('country-dropdown1', 'value'),
     Input('category-dropdown1', 'value'),
     Input('date-range-picker1', 'start_date'),
     Input('date-range-picker1', 'end_date')]
)
def update_graph(selected_country, selected_category, start_date, end_date):
    start_date = pd.Timestamp(start_date)
    end_date = pd.Timestamp(end_date) + pd.offsets.MonthEnd(0)

    filtered_discussions_df = real_data[(real_data['country'] == selected_country) &
                                        (real_data['Category'].apply(lambda x: selected_category in x)) &
                                        (real_data['date'] >= start_date) &
                                        (real_data['date'] <= end_date)]

    if filtered_discussions_df.empty:
        layout = go.Layout(title='No discussions found for the selected criteria',
                           xaxis_title='Date', yaxis_title='Count')
        return {'data': [], 'layout': layout}

    time_diff = end_date - start_date

    if time_diff <= timedelta(days=60):
        freq = 'D'
    elif time_diff <= timedelta(days=365):
        freq = 'W-Mon'
    elif time_diff <= timedelta(days=730):
        freq = '2W-Mon'
    else:
        freq = 'ME'

    discussions_per_week = filtered_discussions_df.resample(freq, on='date').size()

    Q1 = discussions_per_week.quantile(0.25)
    Q3 = discussions_per_week.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.65 * IQR
    upper_bound = Q3 + 1.65 * IQR
    outliers_mask = (discussions_per_week < lower_bound) | (discussions_per_week > upper_bound)
    
    outlier_dates = discussions_per_week.index[outliers_mask] 
    outlier_values = discussions_per_week[outliers_mask]

    actual_start_date = discussions_per_week.index.min()
    actual_end_date = discussions_per_week.index.max()

    filtered_news_df = news_df1[(news_df1['country'] == selected_country) &
                                (news_df1['Category'].apply(lambda x: selected_category in x)) &
                                (news_df1['date'] >= start_date) &
                                (news_df1['date'] <= end_date)]

    outlier_explanations = []
    filtered_news_df['year_month'] = filtered_news_df['date'].dt.to_period('M')
    for date in outlier_dates:
        df = filtered_news_df.copy()
        date_period = date.to_period('M')  # Convert date to period
        # Directly check if the period is in the 'year_month' column
        if date_period in df['year_month'].values:
            explanation = generate_explanation_news(df, selected_country, selected_category, date_period)
        else:
            df = filtered_discussions_df.copy()
            files = get_files_for_date(date,df)
            titles = get_titles_for_date(date,df).tolist()
            if len(files)>10:
                random_indices = random.sample(range(len(files)), 10)
                files = [files[i] for i in random_indices]
                titles = [titles[i] for i in random_indices]
            if files:
                explanation = generate_explanation(files, titles,selected_country, selected_category, date)
            else:
                explanation = "No content available for this date."     


        outlier_explanations.append(explanation)
    discussion_trace = go.Scatter(x=discussions_per_week.index, y=discussions_per_week.values,
                                  mode='lines+markers', name='Discussions', line=dict(color='blue'))

    outlier_trace = go.Scatter(
        x=outlier_dates,
        y=outlier_values,
        mode='markers',
        marker=dict(color='red', symbol='line-ns-open', size=20),
        name='Outliers',
        text=outlier_explanations,
        hoverinfo='text'
    )
    if not filtered_news_df.empty:
        articles_per_week = filtered_news_df.resample(freq, on='date').size()

        # Apply smoothing and normalization
        smoothed_discussions_per_week = smooth_series(discussions_per_week, window_size=3)
        smoothed_articles_per_week = smooth_series(articles_per_week, window_size=3)

        # Normalize series for correlation calculation
        normalized_discussions = normalize_series(smoothed_discussions_per_week)
        normalized_articles = normalize_series(smoothed_articles_per_week)

        if len(normalized_discussions) > 1 and len(normalized_articles) > 1:
            common_index = normalized_discussions.index.intersection(normalized_articles.index)
            discussions_common = normalized_discussions[common_index]
            articles_common = normalized_articles[common_index]
            max_lag = 5  # Define the maximum number of lags to consider
            correlations = calculate_lagged_correlation(discussions_common, articles_common, max_lag)
            best_lag = max(correlations, key=correlations.get)
            best_correlation = correlations[best_lag]
        else:
            best_correlation = 'N/A'
            best_lag = 'N/A'

        correlation_text = f'Pearson Correlation (best lag {best_lag}): {best_correlation:.2f}'

        discussion_trace = go.Scatter(x=discussions_per_week.index, y=discussions_per_week.values,
                                      mode='lines+markers', name='Discussions', line=dict(color='blue'))

        articles_trace = go.Scatter(x=articles_per_week.index, y=articles_per_week.values,
                                    mode='lines+markers', name='News Articles', line=dict(color='red'), yaxis='y2')

        layout = go.Layout(title=f'Discussions from {actual_start_date.strftime("%B %Y")} to {actual_end_date.strftime("%B %Y")} ({country_names[selected_country]}, {selected_category})',
                           xaxis_title='Date', yaxis=dict(title='Discussions Count'),
                           yaxis2=dict(title='News Articles Count', overlaying='y', side='right'),
                           legend=dict(x=0, y=1, traceorder="normal"),
                           annotations=[dict(
                               xref='paper',
                               yref='paper',
                               x=0.95,
                               y=-0.2,
                               text=correlation_text,
                               showarrow=False
                           )])

        fig = go.Figure(data=[discussion_trace, outlier_trace, articles_trace], layout=layout)
    else:
        layout = go.Layout(title=f'Discussions from {actual_start_date.strftime("%B %Y")} to {actual_end_date.strftime("%B %Y")} ({country_names[selected_country]}, {selected_category})',
                           xaxis_title='Date', yaxis=dict(title='Discussions Count'),
                           legend=dict(x=0, y=1, traceorder="normal"),
                           annotations=[dict(
                               xref='paper',
                               yref='paper',
                               x=0.95,
                               y=-0.2,
                               text='Pearson Correlation: N/A',
                               showarrow=False
                           )])

        fig = go.Figure(data=[discussion_trace, outlier_trace], layout=layout)
    return fig

if __name__ == '__main__':
    app.run_server(debug=True)

# %%
# Directory where JSON files are stored
directory = r'C:\Users\user\Desktop'

# List all files in the directory
all_files = os.listdir(directory)
print("All files in directory:", all_files)

# List all available JSON files in the directory
def list_available_files(directory):
    return {f for f in os.listdir(directory) if f.endswith('.json')}

available_files = list_available_files(directory)
print("Available files:", available_files)

# %% [markdown]
# ## 2 and 4 merged

# %%
import pandas as pd
import dash
from datetime import datetime, timedelta
from dash import dcc, html, Input, Output
import plotly.express as px
from wordcloud import WordCloud
import base64
import random
import re
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
import plotly.graph_objs as go
# import openai
# from openai import OpenAI
import json
import os
from io import BytesIO
from translate import Translator
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch.nn.functional as F

full_df = pd.read_csv(r"C:\Users\user\Desktop\v18.csv")
full_df['Category'] = full_df['Category'].apply(json.loads)
full_df['date'] = pd.to_datetime(full_df['date'], format='%Y-%m-%d', errors='coerce')
# full_df['Category'] = full_df['Category'].apply(lambda x: [category.strip() for category in x[0].split(',')])

country_names = {1: 'United States', 2: "United Kingdom", 3: "Israel", 4: "Canada", 5: 'Tunisia'}
wanted_categories = ['Economy', 'Education', 'Environment', 'Foreign Policy', 'Healthcare', 'Judicial System', 'Military', 'Social Issues', 'Other']
df4 = full_df.copy()
sia = SentimentIntensityAnalyzer()

import flask
from bidi.algorithm import get_display
import arabic_reshaper
import spacy
from spacy.lang.en.stop_words import STOP_WORDS as en_stop
from spacy.lang.he.stop_words import STOP_WORDS as he_stop
from spacy.lang.ar.stop_words import STOP_WORDS as ar_stop


def clean_text(text):
    text = re.sub(r'Mr\.|Mrs\.|Ms\.|Dr\.|Hon\.|Rep\.|Sen\.|Speaker|President|Member|Committee|Senate|House|States|America|Congress|Introduced|bill|committee|ways|means', '', text, flags=re.IGNORECASE)
    text = re.sub(r'\(.*?\)', '', text)  # Remove text within parentheses
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra whitespace
    return text
# For English, we can use the same `spacy` model if already loaded
nlp_en = spacy.load('en_core_web_sm')
real_data = full_df.copy()

parliamentary_stop_words_eng = [
    "Mr", "Madam", "Speaker", "President", "Member", "Members", "Honourable", 
    "Minister", "Government", "Opposition", "House", "Parliament", "Chair", 
    "Committee", "Debate", "Motion", "Bill", "Clause", "Question", "Answer", 
    "Vote", "Session", "Meeting", "Point", "Order", "Chairperson", "Colleague", 
    "Colleagues", "Gentleman", "Gentlemen", "Lady", "Ladies", "Sir", "Ma'am", 
    "Secretary", "Cabinet", "Prime", "Deputy", "Leader", "Chief", "Office", 
    "Official", "Policy", "Agenda", "Vote", "Yes", "No", "Abstain",
    "Mr", "Madam", "Speaker", "President", "Member", "Members", "Honourable", 
    "Minister", "Government", "Opposition", "House", "Parliament", "Chair", 
    "Committee", "Debate", "Motion", "Bill", "Clause", "Question", "Answer", 
    "Vote", "Session", "Meeting", "Point", "Order", "Chairperson", "Colleague", 
    "Colleagues", "Gentleman", "Gentlemen", "Lady", "Ladies", "Sir", "Ma'am", 
    "Secretary", "Cabinet", "Prime", "Deputy", "Leader", "Chief", "Office", 
    "Official", "Policy", "Agenda", "Vote", "Yes", "No", "Abstain", "Rt", 
    "Hon", "Lord", "Baroness", "Duke", "Duchess", "Viscount", "Viscountess", 
    "Earl", "Countess", "Marquess", "Marquessate", "Dame", "Majesty", "Prince", 
    "Princess", "Duke", "Duchess", "Archbishop", "Bishop", "Canon", "Reverend", 
    "Chaplain", "Clerk", "Treasurer", "Comptroller", "Usher", "Beadle", "Serjeant", 
    "Clerk", "Principal", "Registrar", "Provost", "Dean", "Bailiff", "Master", 
    "Commissioner", "Councillor", "Alderman", "Sheriff", "Recorder", "Mayor", 
    "Governor", "Agent", "Solicitor", "Advocate", "Prosecutor", "Defendant", 
    "Plaintiff", "Magistrate", "Constable", "Coroner", "Officer", "Inspector", 
    "Detective", "Sergeant", "Corporal", "Lieutenant", "Captain", "Major", 
    "Colonel", "Brigadier", "General", "Admiral", "Marshal", "Warrant", 'lord, gentelman, friend, gentelmen, canada, canadian'
    , 'minister', 'government', 'noble'
]

hebrew_stop_words = [
    "ה", "של", "על", "עם", "ש", "כ", "הם", "אני", "אנחנו", "אתה", "את", "אתם",
    "אתן", "הוא", "היא", "הם", "הן", "זה", "זאת", "אלה", "אלו", "מה", "מי", 
    "לא", "כן", "אם", "או", "כל", "כמו", "כי", "אשר", "אף", "אבל", "עוד", 
    "למה", "איך", "היכן", "כאן", "שם", "איפה", "מתי", "כמה", "איזה", "ליד", 
    "מול", "אחרי", "לפני", "בין", "תחת", "מאחורי", "האם", "כדי", "למרות", 
    "מאוד", "יותר", "פחות", "גם", "רק", "שוב", "כמעט", "בדרך כלל", "לעתים קרובות", 
    "לפעמים", "אף פעם", "תמיד", "פעמים רבות", "מעטים", "רבים", "במידה", "יכול", 
    "יוכל", "מוצע", "ממליץ", "מומלץ", "פרופ'", 'ח"כ', "חברי הכנסת", "מזכיר", 
    "מזכירה", "ממשלה", "אופוזיציה", "יושב ראש", "הצעה", "חוק", "סעיף", "שאלה", 
    "תשובה", "הצבעה", "ישיבה", "ישיבות", "נקודה", "סדר", "חבר", "חברים", "גברת", 
    "גבירותיי", "אדון", "אדונים", "שר", "שרים", "מזכירים", "הנשיא", "ראש הממשלה", 
    'מנכ"ל', "יועץ", "מדיניות", "תכנית", "סדר יום", "כן", "לא", "נמנע", 'הכנסת', 'בוועדה',
    'בוועדת', 'חברי הכנסת', 'הזה' ,'ואני', 'נוכח', 'נוכחת', 'חברת', 'שזה', 'שהוא', 'שלא', 'אינו', 'אינה',
    'הממשלה', 'שאנחנו', 'כבר', 'היום', 'הזאת', 'לך', 'חברי','ולא', 'הייתה', 'בממשלה', 'השר','אבל', 'אחר', 'אחרת', 'אם', 'אנחנו', 'אני', 'את', 'אתה', 
    'באמצע', 'בגלל', 'בין', 'בלי', 'גם', 'דרך', 'היא', 'היה', 
    'היתה', 'הם', 'הן', 'ועוד', 'זאת', 'זה', 'זות', 'יותר', 
    'יש', 'כמו', 'כן', 'לא', 'למה', 'לפני', 'מאוד', 'מה', 
    'מי', 'מכל', 'מכיוון', 'מלא', 'ממש', 'מעט', 'עד', 'על', 
    'עם', 'פה', 'רק', 'שוב', 'תחת', 'אף', 'הכל', 'אף-על-פי', 
    'אף-על-פי-כן', 'אל', 'אולי', 'אז', 'אחת', 'אותה', 'אותו', 
    'אותן', 'אותם', 'אותי', 'אותך', 'אותנו', 'אשר', 'ב', 
    'בא', 'באיזה', 'באיזו', 'באיזו', 'באמת', 'בערך', 'ברור', 
    'בדיוק', 'בזמן', 'בלבד', 'בכלל', 'בכלליות', 'בלי', 'בעבר', 
    'בעצם', 'בפני', 'בקשר', 'ברם', 'בשום', 'גם-כן', 'זאת-אומרת', 
    'יותר-מידי', 'יותר-מדי', 'כיצד', 'כאשר', 'כאן', 'כבר', 
    'ל', 'לאחר', 'לבינתיים', 'לגמרי', 'להיות', 'לו', 'לומר', 
    'למה', 'למעט', 'לעולם', 'לפיכך', 'מאחורי', 'מאחר', 'מדי', 
    'מישהו', 'משום', 'מתחת', 'נא', 'נגד', 'עדיין', 'עוד', 
    'אכן', 'עכשיו', 'עם-זאת', 'עצמה', 'עצמם', 'עצמו', 'עצמי', 
    'פחות', 'פה', 'צד', 'קודם', 'רוב', 'שוב', 'שום', 'שלה', 
    'שלו', 'שלי', 'שלנו', 'תחת', 'אותו', 'אותה', 'אותם', 
    'אותן', 'אותך', 'אותי', 'אתכם', 'אתכן', 'איתו', 'איתך', 
    'איתי', 'איתה', 'איתם', 'איתן', 'כלשהו', 'כלשהי', 'כולם', 
    'כולן', 'כולו', 'כולה', 'כמובן', 'כפי', 'כאילו', 'כן', 
    'כאן', 'כזה', 'כמו', 'כפי', 'כי', 'לכן', 'לעתים', 'מאוד', 
    'מאחר', 'מכל', 'מלבד', 'מן', 'מני', 'ממנו', 'ממנה', 'ממך', 
    'ממני', 'מס', 'נגד', 'נו', 'נאמר', 'נא', 'נראה', 'סוף', 
    'עוד', 'עבור', 'עמו', 'עצמם', 'עצמן', 'עצמו', 'עצמה', 
    'פה', 'במקום', 'בעצם', 'באמת', 'באופן', 'בלי', 'ברור', 
    'בסופו', 'בתוך', 'בדרך', 'במקום', 'בחוץ', 'בתוך', 'יותר', 
    'יחד', 'לבד', 'לבין', 'לגמרי', 'לכן', 'לפיכך', 'מאז', 
    'מאחורי', 'מאיתנו', 'מאיתכם', 'מאיתכן', 'מאותו', 'מאותה', 
    'מאותם', 'מאותן', 'מאחר', 'מאז', 'מדוע', 'מה', 'מהם', 
    'מהן', 'מהי', 'מהו', 'מהן', 'מאיזה', 'מזה', 'מי', 'מי', 
    'מכם', 'מכן', 'מזה', 'מתי', 'מתחת', 'נראה', 'נאמר', 
    'כאן', 'כי', 'כל', 'כלל', 'כלשהו', 'כלשהי', 'כמובן', 
    'כמו', 'כן', 'לא', 'לבד', 'לגמרי', 'לה', 'לו', 'לי', 
    'למה', 'לנו', 'לעולם', 'לפני', 'מאוד', 'מאחר', 'מדה', 
    'מה', 'מהם', 'מהן', 'מי', 'מיליון', 'מכל', 'מלבד', 'מן', 
    'מנין', 'מעט', 'מקום', 'מתוך', 'נגד', 'נראה', 'נא', 
    'נעשה', 'סוף', 'סופי', 'סופית', 'על', 'עליה', 'עליהם', 
    'עליהן', 'עליו', 'עליה', 'עלי', 'עליהם', 'עליהן', 'עצמם', 
    'עצמו', 'עצמה', 'עצמם', 'פה', 'פי', 'צד', 'קודם', 'רק', 
    'שוב', 'שום', 'של', 'שלה', 'שלו', 'שלהם', 'שלהן', 'שלי', 
    'שלנו', 'שלהם', 'שלהן', 'שאם', 'שבו', 'שלה', 'שלו', 'שלי', 
    'שלנו', 'שם', 'שוב', 'שובו', 'תחת', 'תוך',"תודה" ,"שאני", "רבה",
    "התשפ","תשפ", "ט", "ג", "אומר", "אדוני היושה", "היושב", "ראש", "היושב ראש", 
    "בבקשה", "רוצה", "להגיד", "אפשר","שאתה","ואנחנו", "אדוני" ,"זה" ,"צריך", "לעשות", "גם", "אפילו", "אחד", "וגם"
]

stop_words_english = set(nltk.corpus.stopwords.words('english')) | set(parliamentary_stop_words_eng) | set(en_stop)
stop_words_hebrew = set(nltk.corpus.stopwords.words('hebrew')) | set(hebrew_stop_words) | set(he_stop) 
stop_words_arabic = set(nltk.corpus.stopwords.words('arabic')) | set(ar_stop)
real_data['date'] = pd.to_datetime(real_data['date'])


# Load heBERT model and tokenizer
hebrew_tokenizer = AutoTokenizer.from_pretrained("avichr/heBERT_sentiment_analysis")
hebrew_model = AutoModelForSequenceClassification.from_pretrained("avichr/heBERT_sentiment_analysis")

def translate_text(text, src_lang):
    translator = Translator(from_lang=src_lang, to_lang="en")
    try:
        translated_text = translator.translate(text)
        return translated_text
    except Exception as e:
        print(f"Error: {str(e)}")
        return f'Error: {str(e)}'

def sentiment_analysis(partial_path,country = 1):
    d = r'C:\Users\user\Desktop'
    path = os.path.join(d, partial_path)
    sent_dict = {}
    with open(path, 'r') as json_file:
        alltext = json.load(json_file)
    for i in alltext:
        member = i['name'].lower()  # Accessing the name directly
        if len(member) >70:
            continue
        text = i['speech']  # Accessing the speech text directly
        if len(text) > 10000:
            text = text[:10000]
        if country == 5:
            if len(text) > 250:
                text1 = text[:250]
            text = translate_text(text1,'ar')
        sentiment_scores = sia.polarity_scores(text)['compound']
        if member not in sent_dict.keys():
            sent_dict[member] = [float(sentiment_scores), 1]
        else:
            sent_dict[member][0] += float(sentiment_scores)
            sent_dict[member][1] += 1

    for i, j in sent_dict.items():
        sent_dict[i][0] /= sent_dict[i][1]
        sent_dict[i] = round(sent_dict[i][0], 3)
    return sent_dict

def sentiment_score_he(texts):
    # Tokenize the input texts
    inputs = hebrew_tokenizer(texts, return_tensors="pt", padding=True, truncation=True, max_length=256)
    
    # Get the model output
    with torch.no_grad():
        outputs = hebrew_model(**inputs)
    logits = outputs.logits
    
    # Apply softmax to get probabilities
    probs = F.softmax(logits, dim=1)
    
    # Extract positive, neutral, and negative probabilities
    negative_probs = probs[:, 0].tolist()
    positive_probs = probs[:, 2].tolist()
    
    # Calculate the sentiment scores
    sentiments = [pos - neg for pos, neg in zip(positive_probs, negative_probs)]
    
    return sentiments

def sentiment_analysis_hebrew(partial_path):
    d = r'C:\Users\user\Desktop'
    path = os.path.join(d, partial_path)
    sent_dict = {}
    
    with open(path, 'r', encoding='utf-8') as json_file:
        alltext = json.load(json_file)

    # Preprocess texts and members
    texts, members = [], []
    for i in alltext:
        member = i['name'].lower()
        if len(member) > 70:
            continue
        text = i['speech']
        if len(text) > 700:
            text = text[200:700]
        texts.append(text)
        members.append(member)

    # Batch processing
    batch_size = 16
    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i+batch_size]
        batch_members = members[i:i+batch_size]
        sentiment_scores = sentiment_score_he(batch_texts)
        
        for member, sentiment_score in zip(batch_members, sentiment_scores):
            if member not in sent_dict:
                sent_dict[member] = [sentiment_score, 1]
            else:
                sent_dict[member][0] += sentiment_score
                sent_dict[member][1] += 1

    for member, scores in sent_dict.items():
        sent_dict[member][0] /= scores[1]
        sent_dict[member] = round(sent_dict[member][0], 3)
    
    return sent_dict

def sentiment_color(sentiment):
    if sentiment < -0.25:
        return 'red'
    elif sentiment > 0.25:
        return 'green'
    else:
        return 'yellow'

def truncate_title(title, max_length=90):
    try:
        if isinstance(title, str) and len(title) >= max_length:
            return title[:max_length] + '...'
        return title.lower()
    except Exception as e:
        return "Error truncating title"
    
def clean_name(name):
    # Remove titles and other specific words
    name = re.sub(r'Mr\.|Ms\.|Mrs\.|Dr\.|Hon\.|Sir|mr\.|ms\.|mrs\.|dr\.|hon\.|sir|היו"ר|יו"ר|מזכירת|הכנסת|מזכיר', '', name)
    # Remove parentheses and their contents
    name = re.sub(r'\(.*?\)', '', name)
    # Remove trailing colons and any surrounding whitespace
    name = re.sub(r':\s*$', '', name).strip()
    return name

def match_name(name, names_list):
    cleaned_name = clean_name(name)
    pattern = re.compile(r'\b{}\b'.format(re.escape(cleaned_name.lower().strip())))
    matches = [pattern.search(clean_name(n).lower().strip()) for n in names_list]
    matched_names = [names_list[i] for i in range(len(matches)) if matches[i] is not None]
    return matched_names if matched_names else None

df4['truncated_title'] = df4['debate_title'].apply(truncate_title)

CA_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\CA_members.csv')
IL_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\IL_members.csv')
TN_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\TN_members.csv')
UK_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\UK_members.csv')
US_par = pd.read_csv(r'C:\Users\user\Desktop\Data\csv_files\members\US_members.csv')
 
# Define the layout of the dashboard
app = dash.Dash(__name__)
app.layout = html.Div([
    html.H1('Sentiment Analysis & Wordcloud Graph', style={'textAlign': 'center'}),
    html.Div([
        html.Label('Country:'),
        dcc.Dropdown(
            id='country-dropdown2',
            options=[{'label': country_names[country], 'value': country} for country in real_data['country'].unique()],
            value=real_data['country'].unique()[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
        html.Label('Category:'),
        dcc.Dropdown(
            id='category-dropdown2',
            options=[{'label': category, 'value': category} for category in wanted_categories],
            value=wanted_categories[0],
            style={'width': '45%', 'display': 'inline-block'}
        ),
        html.Label('Discussion Title:'),
        dcc.Dropdown(
            id='debate-dropdown2',
            style={'width': '45%', 'display': 'inline-block'}
        ),
    ]),
    html.Div(id='discussion-info4', style={'textAlign': 'center', 'margin': '20px 0', 'fontSize': '24px', 'fontWeight': 'bold'}),
    html.Div([
        dcc.Graph(id='sentiment-graph', style={'width': '65%', 'height': '450px', 'display': 'inline-block'}),
        html.Div(id='wordcloud-container', style={'width': '35%', 'height': '450px', 'display': 'inline-block'})
    ], style={'display': 'flex', 'alignItems': 'stretch', 'justifyContent': 'space-between'}),
    html.Div(["This wordcloud graph visually represents the most frequently used words in the selected discussion.", html.Br(),
              "The size of each word indicates its frequency in the debate. Common parliamentary stopwords have been removed to highlight the key terms discussed."], 
             style={'textAlign': 'left', 'margin': '20px 0', 'fontSize': '16px'})
])

@app.callback(
    [Output('debate-dropdown2', 'options'),
    Output('debate-dropdown2', 'value')],
    [Input('country-dropdown2', 'value'),
    Input('category-dropdown2', 'value')]
)
def update_discussion_options(selected_country, selected_category):
    filtered_df = real_data[real_data['country'] == selected_country]
    if selected_category:
        filtered_df = filtered_df[filtered_df['Category'].apply(lambda x: selected_category in x)]
    
    discussion_options = [{'label': discussion, 'value': discussion} for discussion in filtered_df['debate_title'].unique()]
    if discussion_options:
        selected_discussion = discussion_options[0]['value']
        return discussion_options, selected_discussion
    else:
        return [], None


@app.callback(
    Output('sentiment-graph', 'figure'),
    Output('discussion-info4', 'children'),
    [Input('country-dropdown2', 'value'),
    Input('category-dropdown2', 'value'),
    Input('debate-dropdown2', 'value')]
)
def update_graph(selected_countries, selected_categories, selected_discussions):
    filtered_df = df4[
        (df4['country'] == selected_countries) &
        (df4['Category'].apply(lambda x: selected_categories in x)) &
        (df4['debate_title'].isin([selected_discussions]))
    ]
    
    discussion_date = filtered_df['date'].iloc[0].strftime('%d-%m-%Y')
    discussion_info = f"Country: {country_names[selected_countries]}, Category: {selected_categories}, Date: {discussion_date}"
    
    path = filtered_df['file_path'].tolist()
    sent_dict = {}
    if selected_countries == 4:
        sent_dict = sentiment_analysis(path[0])
        parties_df = CA_par
    elif selected_countries == 3:
        sent_dict = sentiment_analysis_hebrew(path[0])
        parties_df = IL_par
    elif selected_countries == 2:
        sent_dict = sentiment_analysis(path[0])
        parties_df = UK_par
        parties_df['name'] = parties_df['name'].apply(clean_name)
    elif selected_countries == 1:
        sent_dict = sentiment_analysis(path[0])
        parties_df = US_par
    elif selected_countries == 5:
        sent_dict = sentiment_analysis(path[0], 5)
        parties_df = TN_par

    parties_df['startDate'] = pd.to_datetime(parties_df['startDate'])
    parties_df['endDate'] = pd.to_datetime(parties_df['endDate'])

    filtered_parties_df = parties_df[
        (parties_df['startDate'] <= discussion_date) &
        (parties_df['endDate'].isna() | (parties_df['endDate'] >= discussion_date))
    ]

    final_data = []
    reverse_lookup = {clean_name(key): key for key in sent_dict.keys()}
    
    for original_name, sentiment in sent_dict.items():
        cleaned_name = clean_name(original_name)
        if cleaned_name in reverse_lookup:
            matched_names = match_name(cleaned_name, filtered_parties_df['name'].tolist())
            if matched_names:
                for matched_name in matched_names:
                    matched_row = filtered_parties_df[filtered_parties_df['name'] == matched_name]
                    original_matched_name = matched_row['name'].values[0]
                    party = matched_row['party'].values[0]
                    final_data.append((original_matched_name, sentiment, party))
                    break

    if final_data:
        merged_df = pd.DataFrame(final_data, columns=['matched_name', 'sentiment', 'party'])
    else:
        merged_df = pd.DataFrame([
        {'matched_name': name, 'sentiment': sent_dict.get(name, 0), 'party': 'No Party'} 
        for name in sent_dict.keys()
    ])
    
    if 'No Party' in merged_df['party'].unique() and not merged_df['party'].isnull().all():
        unique_parties = merged_df['party'].unique()
        party_to_y = {party: i for i, party in enumerate(unique_parties)}
        party_to_y['No Party'] = 0
    else:
        unique_parties = merged_df['party'].unique()
        party_to_y = {party: i for i, party in enumerate(unique_parties)}

    merged_df['color'] = merged_df['sentiment'].apply(sentiment_color)
    merged_df['y_position'] = merged_df['party'].map(party_to_y)
    
    avg_sentiments = merged_df.groupby('party')['sentiment'].mean().reset_index()
    avg_sentiments['sentiment'] = avg_sentiments['sentiment'].round(3)
    avg_sentiments['y_position'] = avg_sentiments['party'].map(party_to_y)
    avg_sentiments['color'] = avg_sentiments['sentiment'].apply(sentiment_color)
    
    fig = {
        'data': [
            go.Scatter(
                x=merged_df['sentiment'],
                y=merged_df['y_position'],
                text=[f'{row["matched_name"]} (Party: {row["party"]}, Sentiment: {row["sentiment"]})' for _, row in merged_df.iterrows()],
                mode='markers',
                marker={'size': 15, 'color': merged_df['color']},
                name = "Parliament Member"
            ),
            go.Scatter(
            x=avg_sentiments['sentiment'],
            y=avg_sentiments['y_position'],
            text=[f'The {row["party"]} Party Average Sentiment (Party: {row["party"]}, Sentiment: {row["sentiment"]})' for _, row in avg_sentiments.iterrows()],
            mode='markers',
            marker={'size': 20, 'color': avg_sentiments['color'], 'symbol': 'circle', 'opacity': 0.5},
            name='Average Sentiment'
        )
        ],
        'layout': go.Layout(
            title='MPs Sentiment by Party',
            xaxis={'title': 'Sentiment Score'},
            yaxis={'title': 'Party', 'tickvals': list(range(len(unique_parties))), 'ticktext': list(unique_parties)},
            hovermode='closest'
        )
    }
    return fig, discussion_info


@app.callback(
    Output('wordcloud-container', 'children'),
    [Input('debate-dropdown2', 'value'),
    Input('country-dropdown2', 'value'),
    Input('category-dropdown2', 'value')]
)
def update_wordcloud(selected_debate, selected_country, selected_category):
    if selected_debate is None:
        return html.Div(), ""  # Return empty div and empty info if no debate is selected

    filtered_df = real_data[(real_data['debate_title'] == selected_debate) & 
                            (real_data['country'] == selected_country) & 
                            (real_data['Category'].apply(lambda x: selected_category in x))]
    discussion_date = filtered_df['date'].iloc[0].strftime('%Y-%m-%d')  # Format the date to show only the date part
    
    partial_path = filtered_df['file_path'].iloc[0]
    font = r"C:\Users\user\Desktop\OpenSans-Medium.ttf"
    arabic_flag, IL_flag = False, False
    initial_path = r'C:\Users\user\Desktop'
    if selected_country == 3:
        IL_flag = True

    elif selected_country == 5:
        arabic_flag = True
        font = r'C:\Users\user\Desktop\Cairo-VariableFont_slnt,wght.ttf'

    path = os.path.join(initial_path, partial_path)
    with open(path, 'r', encoding='utf-8') as json_file:
        alltext = json.load(json_file)

    full_text = ''
    for i in alltext:
        if len(full_text + i['speech']) < 50000:
            full_text += i['speech']
        else:
            rem = 50000 - len(full_text)
            full_text += i['speech'][:rem]

    cleaned_text = clean_text(full_text)
    if selected_country == 5:
        stop_words = stop_words_arabic
        tokens = [word for word in re.findall(r'\b\w+\b', cleaned_text) if word.lower() not in stop_words]
        preprocessed_text = ' '.join(tokens)
        preprocessed_text = arabic_reshaper.reshape(preprocessed_text)
        preprocessed_text = get_display(preprocessed_text)
    elif selected_country == 3:
        stop_words = stop_words_hebrew
        tokens = [word for word in re.findall(r'\b\w+\b', cleaned_text) if word.lower() not in stop_words]
        preprocessed_text = ' '.join(tokens)
        preprocessed_text = get_display(preprocessed_text)
    else:
        doc = nlp_en(cleaned_text)
        interesting_labels = ["PERSON", "ORG", "GPE", "LAW", "EVENT", "WORK_OF_ART", "DATE", "MONEY", "PRODUCT", "LOC", "FAC", "NORP", "PERCENT", "QUANTITY", "ORDINAL", "CARDINAL"]
        tokens = [ent.text for ent in doc.ents if ent.label_ in interesting_labels]
        tokens += [token.lemma_ for token in doc if token.pos_ in interesting_labels and token.lemma_.lower() not in stop_words_english]
        tokens_filtered_stopwords = [token for token in tokens if token.lower() not in stop_words_english]
        preprocessed_text = ' '.join(tokens_filtered_stopwords)

    if not preprocessed_text.strip():
        return html.Div("No meaningful words to display in the wordcloud.")

    wordcloud = WordCloud(width=400, height=415, background_color='white', font_path=font).generate(preprocessed_text)
    img_data = BytesIO()
    wordcloud.to_image().save(img_data, format='PNG')
    wordcloud_base64 = base64.b64encode(img_data.getvalue()).decode('utf-8')

    text_direction = 'rtl' if selected_country == 3 or selected_country == 5 else 'ltr'
    return html.Img(src='data:image/png;base64,{}'.format(wordcloud_base64), style={'width': '90%', 'height': 'auto', 'direction': text_direction, 'unicode-bidi': 'embed'})



if __name__ == '__main__':
    app.run_server(debug=True)

# %%
errors

# %%
import shutil
import pandas as pd
import os
# full_df = 
# full_df['Category'] = full_df['Category'].apply(json.loads)
# full_df['date'] = pd.to_datetime(full_df['date'], format='%Y-%m-%d', errors='coerce')

base_path = r"C:\Users\user\Desktop"
destination_dir = r"C:\Users\user\Desktop\New folder (2)"

os.makedirs(destination_dir, exist_ok=True)

removed_df = pd.DataFrame(columns=errors.columns)

for index, row in errors.iterrows():
    # Construct the full file path
    full_file_path = os.path.join(base_path, row['file_path'])
    try:

        shutil.move(full_file_path, destination_dir)
    except Exception as e:
        print(e)
#     removed_df = pd.concat([removed_df, pd.DataFrame([row])], ignore_index=True)

#     errors.drop(index, inplace=True)


# errors.reset_index(drop=True, inplace=True)
# removed_df.reset_index(drop=True, inplace=True)

# errors['Category'] = errors['Category'].apply(json.dumps)
# errors.to_csv("full_df_updated.csv", index=False)

# removed_df['Category'] = removed_df['Category'].apply(json.dumps)
# removed_df.to_csv("removed_rows.csv", index=False)

print("Files moved and DataFrames updated successfully.")

# %%
# full_df['Category'] = full_df['Category'].apply(json.loads)
full_df

# %%
test1 = pd.read_csv(r"C:\Users\user\Desktop\stam.csv")
test1['Category'] = test1['Category'].apply(json.loads)
test1['date'] = pd.to_datetime(test1['date'], format='%Y-%m-%d', errors='coerce')

test2 = pd.read_csv(r"C:\Users\user\Desktop\NEW USA 2123.csv")
test2['Category'] = test2['Category'].apply(json.loads)
test2['date'] = pd.to_datetime(test2['date'], format='%Y-%m-%d', errors='coerce')

# %%
test1

# %%
test2

# %%
v3 = pd.concat([test1, full_df, test2], ignore_index=True)
v3

# %%
removed_df
